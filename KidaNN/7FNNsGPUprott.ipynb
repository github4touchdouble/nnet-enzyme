# %%
import h5py, sys, csv, time, os, datetime, math
import torch
from torch.utils.data import DataLoader, Dataset, random_split
from sklearn.model_selection import KFold
import torch.nn as nn
from torch.optim import SGD
from copy import deepcopy
import numpy as np
from sklearn.metrics import roc_curve, f1_score, accuracy_score, auc
import matplotlib.pyplot as plt
from reading_util import filter_unwanted_esm2, H5Dataset
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score
from bootstrapping import bootstrap_statistic
from bootstrapping import calculate_f1, round_to_significance

# %%
# Custom Dataset
class EnzymeDataset(Dataset):
    def __init__(self, data, labels):
        self.data = data
        self.labels = labels

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        return torch.FloatTensor(self.data[idx]).float(), torch.FloatTensor([self.labels[idx]]).float()

# %%
def load_ml_data_emb(path_to_esm2: str, path_to_enzyme_csv: str):
    """
    Reads in the embeddings and the EC numbers from the h5 file and the csv file and labels them accordingly.
    :param path_to_esm2: path to the h5 file
    :param path_to_enzyme_csv: path to the csv file
    :return: X: embeddings, y: EC numbers (labels)
    """

    to_remove = filter_unwanted_esm2(path_to_enzyme_csv, True)

    h5_dataset = H5Dataset(path_to_esm2, path_to_enzyme_csv)

    loader = torch.utils.data.DataLoader(h5_dataset, batch_size=32, shuffle=False)

    # Iterate over batches
    X = []
    y = []

    t0 = time.time()
    for batch in loader:
        emb, header, ec_numbers = batch
        if header not in to_remove:

            ec_class = [int(ec_number.split(".")[0]) for ec_number in ec_numbers]  # here we convert ec to int and do -1
            X.append(emb.numpy())
            y.extend(list(ec_class))

    # Convert the lists to numpy arrays
    X = np.vstack(X)
    y = np.array(y)

    t1 = time.time()

    total = (t1 - t0) / 60

    print(f"LOG: Data loaded in: {round(total, 3)} min")
    print(f"LOG: ESM2 of enzymes: {len(X)}")
    print(f"LOG: Labels of enzymes: {len(y)}")

    return X, y

enzyme_sequences, enzyme_labels = load_ml_data_emb("D:/Uni/PBL/RNN/Dataset/split30_prott5.h5", 'D:/Uni/PBL/RNN/Dataset/split30.csv')
dataset = EnzymeDataset(enzyme_sequences, enzyme_labels)
# Out:
# LOG: 3 Sequences with aa O in D:/Uni/PBL/RNN/Dataset/split30.csv
# LOG: 15 Sequences with aa U in D:/Uni/PBL/RNN/Dataset/split30.csv
# LOG: 203 multifunctional enzymes with diff ec main classes in D:/Uni/PBL/RNN/Dataset/split30.csv
# LOG: 221 entries will be ignored
# D:\Uni\PBL\RNN\reading_util.py:167: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at C:\cb\pytorch_1000000000000\work\torch\csrc\utils\tensor_new.cpp:264.)
#   emb = torch.tensor(hdf_handle[key], dtype=torch.float32).reshape(-1)
# LOG: Data loaded in: 0.078 min
# LOG: ESM2 of enzymes: 9204
# LOG: Labels of enzymes: 9204

# %%
class EnzymeClassifiers(nn.Module):
    def __init__(self, input_dim, num_classes=7):
        super(EnzymeClassifiers, self).__init__()
        self.models = nn.ModuleList([FNN(input_dim) for _ in range(num_classes)])

    def forward(self, x):
        outputs = [model(x) for model in self.models]
        return outputs

# %%
class FNN(nn.Module):
    def __init__(self, input_dim):
        super(FNN, self).__init__()
        self.fc1 = nn.Linear(input_dim, 512)
        self.fc2 = nn.Linear(512, 256)
        self.fc3 = nn.Linear(256, 1)  # Binary classification output
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        x = self.sigmoid(self.fc3(x))
        return x

# %%
# Training function
def train_one_epoch(enzyme_class, model, dataloader, criterion, optimizer):
    '''
    model.train()
    running_loss = 0.0
    
    for inputs, labels in dataloader:
        inputs, labels = inputs.cuda(), labels.cuda()
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels.float())
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
        correct_predictions = (outputs.round() == labels).float().sum()
        accuracy = correct_predictions / labels.size(0)
    return loss.item(), accuracy.item()
    '''
    
    model.train()
    total_loss = 0.0
    total_correct = 0
    total_samples = 0

    for data, labels in dataloader:       
        # Transfer data and labels to GPU
        data, labels = data.cuda(), labels.cuda()
        # Forward pass
        outputs = model(data)
        
        # Compute the loss
        loss = criterion(outputs, labels)
        total_loss += loss.item()
        
        # Compute accuracy
        correct_predictions = (outputs.round() == labels).float().sum()
        total_correct += correct_predictions.item()
        total_samples += labels.size(0)

        # Backward pass and optimization
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    
    # Calculate average loss and accuracy
    average_loss = total_loss / len(train_loader)
    average_accuracy = total_correct / total_samples

    return average_loss, average_accuracy
    
# Validation function
def validate(enzyme_class, model, dataloader, criterion):
    model.eval()
    val_loss = 0.0
    total_correct = 0
    total_samples = 0
    all_labels = []
    all_pred = []
    with torch.no_grad():
        for inputs, labels in dataloader:
            inputs, labels = inputs.cuda(), labels.cuda()
            outputs = model(inputs)
            loss = criterion(outputs, labels.float())
            val_loss += loss.item()
            
            # Compute accuracy
            correct_predictions = (outputs.round() == labels).float().sum()
            total_correct += correct_predictions.item()
            total_samples += labels.size(0)
            all_labels.append(labels)
            all_pred.append(outputs)
            
    
    
    # Calculate average loss and accuracy
    average_loss = val_loss / len(dataloader)
    average_accuracy = total_correct / total_samples

    return average_loss, average_accuracy, all_labels, all_pred

# %%
def generate_unique_filename(base_name: str, extension: str=".pt") -> str:
    """
    Generate a unique filename by appending current date-time.
    
    :param base_name: Base name for the file
    :param extension: Extension for the file. Default is ".pth"
    
    :return: A unique filename
    """
    current_time = datetime.datetime.now().strftime('%Y%m%d%H%M%S')
    unique_name = f"{base_name}_{current_time}{extension}"
    
    # Check if filename already exists, although it's unlikely due to date-time precision
    while os.path.exists(unique_name):
        current_time = datetime.datetime.now().strftime('%Y%m%d%H%M%S')
        unique_name = f"{base_name}_{current_time}{extension}"
    
    return unique_name

# %%
models = []
lr = 0.01
epochs = 25
kf = KFold(n_splits=5)
enzyme_classifier = EnzymeClassifiers(1024).cuda().float()
patience = 5
all_labels = [[],[],[],[],[],[],[]]
all_pred =  [[],[],[],[],[],[],[]]


for enzyme_class in range(1, 8):
    print(f"Training for enzyme class {enzyme_class}")
    binary_labels = [1 if label == enzyme_class else 0 for label in enzyme_labels]
    dataset = EnzymeDataset(enzyme_sequences, binary_labels)
    current_model = enzyme_classifier.models[enzyme_class-1]
    criterion = nn.BCELoss()
    optimizer = SGD(current_model.parameters(), lr=lr)
    best_model_for_class = None
    best_val_loss = float('inf')
    no_improve_count = 0  # Initialize the counter for early stopping

    for train_idx, val_idx in kf.split(dataset):
        train_subsampler = torch.utils.data.SubsetRandomSampler(train_idx)
        val_subsampler = torch.utils.data.SubsetRandomSampler(val_idx)
        train_loader = DataLoader(dataset, batch_size=32, sampler=train_subsampler)
        val_loader = DataLoader(dataset, batch_size=32, sampler=val_subsampler)
        for epoch in range(epochs):
            train_loss, train_accuracy = train_one_epoch(enzyme_class, current_model, train_loader, criterion, optimizer)
            val_loss, val_accuracy, all_labels[enzyme_class-1], all_pred[enzyme_class-1] = validate(enzyme_class, current_model, val_loader, criterion)
            '''
            # Early stopping check
            if val_loss < best_val_loss:
                best_val_loss = val_loss
                no_improve_count = 0  # Reset counter
                
            else:
                no_improve_count += 1
            '''
            best_model_for_class = deepcopy(current_model)
            print(f"Fold [{train_idx[0]+1}/{kf.get_n_splits()}] - Epoch {epoch+1}/{epochs} - Train Loss: {train_loss:.4f}, Train Accuracy: {train_accuracy:.4f}, Validation Loss: {val_loss:.4f}, Validation Accuracy: {val_accuracy:.4f}")
            
            overfitting_metric = train_accuracy - val_accuracy
            SOME_THRESHOLD = 0.1  
            if overfitting_metric > SOME_THRESHOLD:
                print(f"Warning: Model might be overfitting. Gap: {overfitting_metric:.4f}")

            """if no_improve_count >= patience:
                print("Early stopping due to no improvement in validation loss for 5 consecutive epochs.")
                break  # Break out of the training loop for this fold"""
                
        # Optionally, you can reset the no_improve_count for each new fold
        no_improve_count = 0

    models.append(best_model_for_class)
    
# Save models
unique_filename = generate_unique_filename("all_enzyme_classifiers")
torch.save(enzyme_classifier.state_dict(), unique_filename)
print(f"All models saved in {unique_filename}")
# Out:
# Training for enzyme class 1
# Fold [1842/5] - Epoch 1/25 - Train Loss: 0.5473, Train Accuracy: 0.8688, Validation Loss: 0.4772, Validation Accuracy: 0.8577
# Fold [1842/5] - Epoch 2/25 - Train Loss: 0.4305, Train Accuracy: 0.8688, Validation Loss: 0.4222, Validation Accuracy: 0.8577
# Fold [1842/5] - Epoch 3/25 - Train Loss: 0.4015, Train Accuracy: 0.8688, Validation Loss: 0.4096, Validation Accuracy: 0.8577
# Fold [1842/5] - Epoch 4/25 - Train Loss: 0.3890, Train Accuracy: 0.8688, Validation Loss: 0.4069, Validation Accuracy: 0.8577
# Fold [1842/5] - Epoch 5/25 - Train Loss: 0.3865, Train Accuracy: 0.8688, Validation Loss: 0.4066, Validation Accuracy: 0.8577
# Fold [1842/5] - Epoch 6/25 - Train Loss: 0.3857, Train Accuracy: 0.8688, Validation Loss: 0.4074, Validation Accuracy: 0.8577
# Fold [1842/5] - Epoch 7/25 - Train Loss: 0.3876, Train Accuracy: 0.8688, Validation Loss: 0.4078, Validation Accuracy: 0.8577
# Fold [1842/5] - Epoch 8/25 - Train Loss: 0.3870, Train Accuracy: 0.8688, Validation Loss: 0.4083, Validation Accuracy: 0.8577
# Fold [1842/5] - Epoch 9/25 - Train Loss: 0.3840, Train Accuracy: 0.8688, Validation Loss: 0.4060, Validation Accuracy: 0.8577
# Fold [1842/5] - Epoch 10/25 - Train Loss: 0.3834, Train Accuracy: 0.8688, Validation Loss: 0.4057, Validation Accuracy: 0.8577
# Fold [1842/5] - Epoch 11/25 - Train Loss: 0.3826, Train Accuracy: 0.8688, Validation Loss: 0.4041, Validation Accuracy: 0.8577
# Fold [1842/5] - Epoch 12/25 - Train Loss: 0.3819, Train Accuracy: 0.8688, Validation Loss: 0.4044, Validation Accuracy: 0.8577
# Fold [1842/5] - Epoch 13/25 - Train Loss: 0.3810, Train Accuracy: 0.8688, Validation Loss: 0.4038, Validation Accuracy: 0.8577
# Fold [1842/5] - Epoch 14/25 - Train Loss: 0.3800, Train Accuracy: 0.8688, Validation Loss: 0.4039, Validation Accuracy: 0.8577
# Fold [1842/5] - Epoch 15/25 - Train Loss: 0.3790, Train Accuracy: 0.8688, Validation Loss: 0.4011, Validation Accuracy: 0.8577
# Fold [1842/5] - Epoch 16/25 - Train Loss: 0.3802, Train Accuracy: 0.8688, Validation Loss: 0.4034, Validation Accuracy: 0.8577
# Fold [1842/5] - Epoch 17/25 - Train Loss: 0.3764, Train Accuracy: 0.8688, Validation Loss: 0.3998, Validation Accuracy: 0.8577
# Fold [1842/5] - Epoch 18/25 - Train Loss: 0.3748, Train Accuracy: 0.8688, Validation Loss: 0.4002, Validation Accuracy: 0.8577
# Fold [1842/5] - Epoch 19/25 - Train Loss: 0.3731, Train Accuracy: 0.8688, Validation Loss: 0.3977, Validation Accuracy: 0.8577
# Fold [1842/5] - Epoch 20/25 - Train Loss: 0.3710, Train Accuracy: 0.8688, Validation Loss: 0.3953, Validation Accuracy: 0.8577
# Fold [1842/5] - Epoch 21/25 - Train Loss: 0.3710, Train Accuracy: 0.8688, Validation Loss: 0.3946, Validation Accuracy: 0.8577
# Fold [1842/5] - Epoch 22/25 - Train Loss: 0.3660, Train Accuracy: 0.8688, Validation Loss: 0.3898, Validation Accuracy: 0.8577
# Fold [1842/5] - Epoch 23/25 - Train Loss: 0.3630, Train Accuracy: 0.8688, Validation Loss: 0.3881, Validation Accuracy: 0.8577
# Fold [1842/5] - Epoch 24/25 - Train Loss: 0.3596, Train Accuracy: 0.8688, Validation Loss: 0.3849, Validation Accuracy: 0.8577
# Fold [1842/5] - Epoch 25/25 - Train Loss: 0.3577, Train Accuracy: 0.8688, Validation Loss: 0.3814, Validation Accuracy: 0.8577
# Fold [1/5] - Epoch 1/25 - Train Loss: 0.3594, Train Accuracy: 0.8653, Validation Loss: 0.3450, Validation Accuracy: 0.8718
# Fold [1/5] - Epoch 2/25 - Train Loss: 0.3566, Train Accuracy: 0.8653, Validation Loss: 0.3416, Validation Accuracy: 0.8718
# Fold [1/5] - Epoch 3/25 - Train Loss: 0.3497, Train Accuracy: 0.8653, Validation Loss: 0.3347, Validation Accuracy: 0.8718
# Fold [1/5] - Epoch 4/25 - Train Loss: 0.3461, Train Accuracy: 0.8653, Validation Loss: 0.3316, Validation Accuracy: 0.8718
# Fold [1/5] - Epoch 5/25 - Train Loss: 0.3383, Train Accuracy: 0.8653, Validation Loss: 0.3246, Validation Accuracy: 0.8718
# Fold [1/5] - Epoch 6/25 - Train Loss: 0.3324, Train Accuracy: 0.8653, Validation Loss: 0.3204, Validation Accuracy: 0.8718
# Fold [1/5] - Epoch 7/25 - Train Loss: 0.3276, Train Accuracy: 0.8653, Validation Loss: 0.3140, Validation Accuracy: 0.8718
# Fold [1/5] - Epoch 8/25 - Train Loss: 0.3215, Train Accuracy: 0.8653, Validation Loss: 0.3070, Validation Accuracy: 0.8718
# Fold [1/5] - Epoch 9/25 - Train Loss: 0.3155, Train Accuracy: 0.8653, Validation Loss: 0.3008, Validation Accuracy: 0.8718
# Fold [1/5] - Epoch 10/25 - Train Loss: 0.3082, Train Accuracy: 0.8653, Validation Loss: 0.2974, Validation Accuracy: 0.8718
# Fold [1/5] - Epoch 11/25 - Train Loss: 0.3053, Train Accuracy: 0.8653, Validation Loss: 0.2917, Validation Accuracy: 0.8718
# Fold [1/5] - Epoch 12/25 - Train Loss: 0.2976, Train Accuracy: 0.8653, Validation Loss: 0.2862, Validation Accuracy: 0.8718
# Fold [1/5] - Epoch 13/25 - Train Loss: 0.2917, Train Accuracy: 0.8653, Validation Loss: 0.2820, Validation Accuracy: 0.8718
# Fold [1/5] - Epoch 14/25 - Train Loss: 0.2865, Train Accuracy: 0.8653, Validation Loss: 0.2791, Validation Accuracy: 0.8718
# Fold [1/5] - Epoch 15/25 - Train Loss: 0.2848, Train Accuracy: 0.8653, Validation Loss: 0.2742, Validation Accuracy: 0.8718
# Fold [1/5] - Epoch 16/25 - Train Loss: 0.2760, Train Accuracy: 0.8653, Validation Loss: 0.2680, Validation Accuracy: 0.8718
# Fold [1/5] - Epoch 17/25 - Train Loss: 0.2719, Train Accuracy: 0.8653, Validation Loss: 0.2651, Validation Accuracy: 0.8718
# Fold [1/5] - Epoch 18/25 - Train Loss: 0.2660, Train Accuracy: 0.8653, Validation Loss: 0.2588, Validation Accuracy: 0.8718
# Fold [1/5] - Epoch 19/25 - Train Loss: 0.2613, Train Accuracy: 0.8653, Validation Loss: 0.2569, Validation Accuracy: 0.8718
# Fold [1/5] - Epoch 20/25 - Train Loss: 0.2577, Train Accuracy: 0.8653, Validation Loss: 0.2509, Validation Accuracy: 0.8718
# Fold [1/5] - Epoch 21/25 - Train Loss: 0.2510, Train Accuracy: 0.8698, Validation Loss: 0.2469, Validation Accuracy: 0.8881
# Fold [1/5] - Epoch 22/25 - Train Loss: 0.2486, Train Accuracy: 0.8881, Validation Loss: 0.2415, Validation Accuracy: 0.9001
# Fold [1/5] - Epoch 23/25 - Train Loss: 0.2428, Train Accuracy: 0.8950, Validation Loss: 0.2416, Validation Accuracy: 0.9071
# Fold [1/5] - Epoch 24/25 - Train Loss: 0.2381, Train Accuracy: 0.8994, Validation Loss: 0.2362, Validation Accuracy: 0.9055
# Fold [1/5] - Epoch 25/25 - Train Loss: 0.2332, Train Accuracy: 0.9014, Validation Loss: 0.2322, Validation Accuracy: 0.9055
# Fold [1/5] - Epoch 1/25 - Train Loss: 0.2317, Train Accuracy: 0.9029, Validation Loss: 0.2179, Validation Accuracy: 0.8995
# Fold [1/5] - Epoch 2/25 - Train Loss: 0.2266, Train Accuracy: 0.9051, Validation Loss: 0.2146, Validation Accuracy: 0.9082
# Fold [1/5] - Epoch 3/25 - Train Loss: 0.2225, Train Accuracy: 0.9070, Validation Loss: 0.2109, Validation Accuracy: 0.9229
# Fold [1/5] - Epoch 4/25 - Train Loss: 0.2191, Train Accuracy: 0.9085, Validation Loss: 0.2079, Validation Accuracy: 0.9125
# Fold [1/5] - Epoch 5/25 - Train Loss: 0.2153, Train Accuracy: 0.9098, Validation Loss: 0.2033, Validation Accuracy: 0.9250
# Fold [1/5] - Epoch 6/25 - Train Loss: 0.2151, Train Accuracy: 0.9127, Validation Loss: 0.2002, Validation Accuracy: 0.9256
# Fold [1/5] - Epoch 7/25 - Train Loss: 0.2096, Train Accuracy: 0.9135, Validation Loss: 0.1974, Validation Accuracy: 0.9261
# Fold [1/5] - Epoch 8/25 - Train Loss: 0.2052, Train Accuracy: 0.9154, Validation Loss: 0.1949, Validation Accuracy: 0.9223
# Fold [1/5] - Epoch 9/25 - Train Loss: 0.2022, Train Accuracy: 0.9169, Validation Loss: 0.1919, Validation Accuracy: 0.9240
# Fold [1/5] - Epoch 10/25 - Train Loss: 0.2005, Train Accuracy: 0.9192, Validation Loss: 0.1894, Validation Accuracy: 0.9256
# Fold [1/5] - Epoch 11/25 - Train Loss: 0.1958, Train Accuracy: 0.9184, Validation Loss: 0.1887, Validation Accuracy: 0.9245
# Fold [1/5] - Epoch 12/25 - Train Loss: 0.1942, Train Accuracy: 0.9223, Validation Loss: 0.1891, Validation Accuracy: 0.9305
# Fold [1/5] - Epoch 13/25 - Train Loss: 0.1899, Train Accuracy: 0.9227, Validation Loss: 0.1833, Validation Accuracy: 0.9256
# Fold [1/5] - Epoch 14/25 - Train Loss: 0.1873, Train Accuracy: 0.9241, Validation Loss: 0.1819, Validation Accuracy: 0.9267
# Fold [1/5] - Epoch 15/25 - Train Loss: 0.1861, Train Accuracy: 0.9265, Validation Loss: 0.1846, Validation Accuracy: 0.9202
# Fold [1/5] - Epoch 16/25 - Train Loss: 0.1829, Train Accuracy: 0.9260, Validation Loss: 0.1778, Validation Accuracy: 0.9283
# Fold [1/5] - Epoch 17/25 - Train Loss: 0.1801, Train Accuracy: 0.9265, Validation Loss: 0.1757, Validation Accuracy: 0.9332
# Fold [1/5] - Epoch 18/25 - Train Loss: 0.1794, Train Accuracy: 0.9288, Validation Loss: 0.1761, Validation Accuracy: 0.9364
# Fold [1/5] - Epoch 19/25 - Train Loss: 0.1778, Train Accuracy: 0.9306, Validation Loss: 0.1754, Validation Accuracy: 0.9272
# Fold [1/5] - Epoch 20/25 - Train Loss: 0.1738, Train Accuracy: 0.9315, Validation Loss: 0.1718, Validation Accuracy: 0.9332
# Fold [1/5] - Epoch 21/25 - Train Loss: 0.1719, Train Accuracy: 0.9328, Validation Loss: 0.1706, Validation Accuracy: 0.9337
# Fold [1/5] - Epoch 22/25 - Train Loss: 0.1698, Train Accuracy: 0.9329, Validation Loss: 0.1702, Validation Accuracy: 0.9326
# Fold [1/5] - Epoch 23/25 - Train Loss: 0.1679, Train Accuracy: 0.9340, Validation Loss: 0.1702, Validation Accuracy: 0.9370
# Fold [1/5] - Epoch 24/25 - Train Loss: 0.1661, Train Accuracy: 0.9366, Validation Loss: 0.1699, Validation Accuracy: 0.9321
# Fold [1/5] - Epoch 25/25 - Train Loss: 0.1650, Train Accuracy: 0.9347, Validation Loss: 0.1669, Validation Accuracy: 0.9370
# Fold [1/5] - Epoch 1/25 - Train Loss: 0.1651, Train Accuracy: 0.9362, Validation Loss: 0.1545, Validation Accuracy: 0.9419
# Fold [1/5] - Epoch 2/25 - Train Loss: 0.1647, Train Accuracy: 0.9358, Validation Loss: 0.1549, Validation Accuracy: 0.9392
# Fold [1/5] - Epoch 3/25 - Train Loss: 0.1618, Train Accuracy: 0.9367, Validation Loss: 0.1538, Validation Accuracy: 0.9408
# Fold [1/5] - Epoch 4/25 - Train Loss: 0.1603, Train Accuracy: 0.9377, Validation Loss: 0.1532, Validation Accuracy: 0.9413
# Fold [1/5] - Epoch 5/25 - Train Loss: 0.1582, Train Accuracy: 0.9377, Validation Loss: 0.1523, Validation Accuracy: 0.9413
# Fold [1/5] - Epoch 6/25 - Train Loss: 0.1573, Train Accuracy: 0.9387, Validation Loss: 0.1540, Validation Accuracy: 0.9424
# Fold [1/5] - Epoch 7/25 - Train Loss: 0.1552, Train Accuracy: 0.9389, Validation Loss: 0.1527, Validation Accuracy: 0.9419
# Fold [1/5] - Epoch 8/25 - Train Loss: 0.1533, Train Accuracy: 0.9408, Validation Loss: 0.1531, Validation Accuracy: 0.9446
# Fold [1/5] - Epoch 9/25 - Train Loss: 0.1523, Train Accuracy: 0.9404, Validation Loss: 0.1545, Validation Accuracy: 0.9370
# Fold [1/5] - Epoch 10/25 - Train Loss: 0.1507, Train Accuracy: 0.9397, Validation Loss: 0.1501, Validation Accuracy: 0.9381
# Fold [1/5] - Epoch 11/25 - Train Loss: 0.1495, Train Accuracy: 0.9411, Validation Loss: 0.1494, Validation Accuracy: 0.9419
# Fold [1/5] - Epoch 12/25 - Train Loss: 0.1512, Train Accuracy: 0.9415, Validation Loss: 0.1489, Validation Accuracy: 0.9430
# Fold [1/5] - Epoch 13/25 - Train Loss: 0.1463, Train Accuracy: 0.9445, Validation Loss: 0.1501, Validation Accuracy: 0.9408
# Fold [1/5] - Epoch 14/25 - Train Loss: 0.1454, Train Accuracy: 0.9426, Validation Loss: 0.1492, Validation Accuracy: 0.9381
# Fold [1/5] - Epoch 15/25 - Train Loss: 0.1440, Train Accuracy: 0.9430, Validation Loss: 0.1495, Validation Accuracy: 0.9392
# Fold [1/5] - Epoch 16/25 - Train Loss: 0.1431, Train Accuracy: 0.9442, Validation Loss: 0.1474, Validation Accuracy: 0.9408
# Fold [1/5] - Epoch 17/25 - Train Loss: 0.1412, Train Accuracy: 0.9461, Validation Loss: 0.1468, Validation Accuracy: 0.9430
# Fold [1/5] - Epoch 18/25 - Train Loss: 0.1425, Train Accuracy: 0.9449, Validation Loss: 0.1589, Validation Accuracy: 0.9364
# Fold [1/5] - Epoch 19/25 - Train Loss: 0.1396, Train Accuracy: 0.9445, Validation Loss: 0.1460, Validation Accuracy: 0.9392
# Fold [1/5] - Epoch 20/25 - Train Loss: 0.1381, Train Accuracy: 0.9457, Validation Loss: 0.1459, Validation Accuracy: 0.9435
# Fold [1/5] - Epoch 21/25 - Train Loss: 0.1367, Train Accuracy: 0.9470, Validation Loss: 0.1455, Validation Accuracy: 0.9408
# Fold [1/5] - Epoch 22/25 - Train Loss: 0.1359, Train Accuracy: 0.9476, Validation Loss: 0.1463, Validation Accuracy: 0.9402
# Fold [1/5] - Epoch 23/25 - Train Loss: 0.1359, Train Accuracy: 0.9465, Validation Loss: 0.1538, Validation Accuracy: 0.9348
# Fold [1/5] - Epoch 24/25 - Train Loss: 0.1346, Train Accuracy: 0.9493, Validation Loss: 0.1579, Validation Accuracy: 0.9402
# Fold [1/5] - Epoch 25/25 - Train Loss: 0.1324, Train Accuracy: 0.9481, Validation Loss: 0.1453, Validation Accuracy: 0.9419
# Fold [1/5] - Epoch 1/25 - Train Loss: 0.1387, Train Accuracy: 0.9450, Validation Loss: 0.1270, Validation Accuracy: 0.9598
# Fold [1/5] - Epoch 2/25 - Train Loss: 0.1356, Train Accuracy: 0.9479, Validation Loss: 0.1265, Validation Accuracy: 0.9598
# Fold [1/5] - Epoch 3/25 - Train Loss: 0.1341, Train Accuracy: 0.9484, Validation Loss: 0.1225, Validation Accuracy: 0.9576
# Fold [1/5] - Epoch 4/25 - Train Loss: 0.1331, Train Accuracy: 0.9498, Validation Loss: 0.1232, Validation Accuracy: 0.9592
# Fold [1/5] - Epoch 5/25 - Train Loss: 0.1310, Train Accuracy: 0.9507, Validation Loss: 0.1244, Validation Accuracy: 0.9560
# Fold [1/5] - Epoch 6/25 - Train Loss: 0.1305, Train Accuracy: 0.9500, Validation Loss: 0.1224, Validation Accuracy: 0.9560
# Fold [1/5] - Epoch 7/25 - Train Loss: 0.1293, Train Accuracy: 0.9514, Validation Loss: 0.1261, Validation Accuracy: 0.9582
# Fold [1/5] - Epoch 8/25 - Train Loss: 0.1276, Train Accuracy: 0.9527, Validation Loss: 0.1231, Validation Accuracy: 0.9549
# Fold [1/5] - Epoch 9/25 - Train Loss: 0.1285, Train Accuracy: 0.9522, Validation Loss: 0.1370, Validation Accuracy: 0.9543
# Fold [1/5] - Epoch 10/25 - Train Loss: 0.1268, Train Accuracy: 0.9518, Validation Loss: 0.1281, Validation Accuracy: 0.9505
# Fold [1/5] - Epoch 11/25 - Train Loss: 0.1245, Train Accuracy: 0.9534, Validation Loss: 0.1259, Validation Accuracy: 0.9533
# Fold [1/5] - Epoch 12/25 - Train Loss: 0.1238, Train Accuracy: 0.9551, Validation Loss: 0.1232, Validation Accuracy: 0.9560
# Fold [1/5] - Epoch 13/25 - Train Loss: 0.1222, Train Accuracy: 0.9546, Validation Loss: 0.1242, Validation Accuracy: 0.9576
# Fold [1/5] - Epoch 14/25 - Train Loss: 0.1228, Train Accuracy: 0.9553, Validation Loss: 0.1241, Validation Accuracy: 0.9571
# Fold [1/5] - Epoch 15/25 - Train Loss: 0.1208, Train Accuracy: 0.9544, Validation Loss: 0.1228, Validation Accuracy: 0.9543
# Fold [1/5] - Epoch 16/25 - Train Loss: 0.1207, Train Accuracy: 0.9561, Validation Loss: 0.1294, Validation Accuracy: 0.9576
# Fold [1/5] - Epoch 17/25 - Train Loss: 0.1189, Train Accuracy: 0.9551, Validation Loss: 0.1237, Validation Accuracy: 0.9565
# Fold [1/5] - Epoch 18/25 - Train Loss: 0.1174, Train Accuracy: 0.9565, Validation Loss: 0.1226, Validation Accuracy: 0.9549
# Fold [1/5] - Epoch 19/25 - Train Loss: 0.1170, Train Accuracy: 0.9557, Validation Loss: 0.1215, Validation Accuracy: 0.9543
# Fold [1/5] - Epoch 20/25 - Train Loss: 0.1176, Train Accuracy: 0.9578, Validation Loss: 0.1247, Validation Accuracy: 0.9571
# Fold [1/5] - Epoch 21/25 - Train Loss: 0.1149, Train Accuracy: 0.9565, Validation Loss: 0.1235, Validation Accuracy: 0.9543
# Fold [1/5] - Epoch 22/25 - Train Loss: 0.1138, Train Accuracy: 0.9582, Validation Loss: 0.1218, Validation Accuracy: 0.9576
# Fold [1/5] - Epoch 23/25 - Train Loss: 0.1133, Train Accuracy: 0.9570, Validation Loss: 0.1224, Validation Accuracy: 0.9582
# Fold [1/5] - Epoch 24/25 - Train Loss: 0.1122, Train Accuracy: 0.9575, Validation Loss: 0.1251, Validation Accuracy: 0.9522
# Fold [1/5] - Epoch 25/25 - Train Loss: 0.1112, Train Accuracy: 0.9583, Validation Loss: 0.1226, Validation Accuracy: 0.9549
# Training for enzyme class 2
# Fold [1842/5] - Epoch 1/25 - Train Loss: 0.6870, Train Accuracy: 0.5710, Validation Loss: 0.6743, Validation Accuracy: 0.6312
# Fold [1842/5] - Epoch 2/25 - Train Loss: 0.6800, Train Accuracy: 0.5881, Validation Loss: 0.6676, Validation Accuracy: 0.6312
# Fold [1842/5] - Epoch 3/25 - Train Loss: 0.6774, Train Accuracy: 0.5881, Validation Loss: 0.6644, Validation Accuracy: 0.6312
# Fold [1842/5] - Epoch 4/25 - Train Loss: 0.6772, Train Accuracy: 0.5881, Validation Loss: 0.6624, Validation Accuracy: 0.6312
# Fold [1842/5] - Epoch 5/25 - Train Loss: 0.6765, Train Accuracy: 0.5881, Validation Loss: 0.6619, Validation Accuracy: 0.6312
# Fold [1842/5] - Epoch 6/25 - Train Loss: 0.6762, Train Accuracy: 0.5881, Validation Loss: 0.6615, Validation Accuracy: 0.6312
# Fold [1842/5] - Epoch 7/25 - Train Loss: 0.6763, Train Accuracy: 0.5881, Validation Loss: 0.6616, Validation Accuracy: 0.6312
# Fold [1842/5] - Epoch 8/25 - Train Loss: 0.6755, Train Accuracy: 0.5881, Validation Loss: 0.6612, Validation Accuracy: 0.6312
# Fold [1842/5] - Epoch 9/25 - Train Loss: 0.6751, Train Accuracy: 0.5881, Validation Loss: 0.6603, Validation Accuracy: 0.6312
# Fold [1842/5] - Epoch 10/25 - Train Loss: 0.6747, Train Accuracy: 0.5881, Validation Loss: 0.6602, Validation Accuracy: 0.6312
# Fold [1842/5] - Epoch 11/25 - Train Loss: 0.6742, Train Accuracy: 0.5881, Validation Loss: 0.6595, Validation Accuracy: 0.6312
# Fold [1842/5] - Epoch 12/25 - Train Loss: 0.6736, Train Accuracy: 0.5881, Validation Loss: 0.6599, Validation Accuracy: 0.6312
# Fold [1842/5] - Epoch 13/25 - Train Loss: 0.6734, Train Accuracy: 0.5881, Validation Loss: 0.6582, Validation Accuracy: 0.6312
# Fold [1842/5] - Epoch 14/25 - Train Loss: 0.6721, Train Accuracy: 0.5881, Validation Loss: 0.6582, Validation Accuracy: 0.6312
# Fold [1842/5] - Epoch 15/25 - Train Loss: 0.6711, Train Accuracy: 0.5881, Validation Loss: 0.6568, Validation Accuracy: 0.6312
# Fold [1842/5] - Epoch 16/25 - Train Loss: 0.6709, Train Accuracy: 0.5881, Validation Loss: 0.6569, Validation Accuracy: 0.6312
# Fold [1842/5] - Epoch 17/25 - Train Loss: 0.6686, Train Accuracy: 0.5881, Validation Loss: 0.6546, Validation Accuracy: 0.6312
# Fold [1842/5] - Epoch 18/25 - Train Loss: 0.6669, Train Accuracy: 0.5881, Validation Loss: 0.6543, Validation Accuracy: 0.6312
# Fold [1842/5] - Epoch 19/25 - Train Loss: 0.6644, Train Accuracy: 0.5881, Validation Loss: 0.6519, Validation Accuracy: 0.6312
# Fold [1842/5] - Epoch 20/25 - Train Loss: 0.6625, Train Accuracy: 0.5881, Validation Loss: 0.6505, Validation Accuracy: 0.6312
# Fold [1842/5] - Epoch 21/25 - Train Loss: 0.6593, Train Accuracy: 0.5881, Validation Loss: 0.6474, Validation Accuracy: 0.6312
# Fold [1842/5] - Epoch 22/25 - Train Loss: 0.6564, Train Accuracy: 0.5886, Validation Loss: 0.6440, Validation Accuracy: 0.6312
# Fold [1842/5] - Epoch 23/25 - Train Loss: 0.6514, Train Accuracy: 0.5919, Validation Loss: 0.6401, Validation Accuracy: 0.6328
# Fold [1842/5] - Epoch 24/25 - Train Loss: 0.6462, Train Accuracy: 0.6074, Validation Loss: 0.6361, Validation Accuracy: 0.6388
# Fold [1842/5] - Epoch 25/25 - Train Loss: 0.6401, Train Accuracy: 0.6212, Validation Loss: 0.6314, Validation Accuracy: 0.6562
# Fold [1/5] - Epoch 1/25 - Train Loss: 0.6357, Train Accuracy: 0.6400, Validation Loss: 0.6174, Validation Accuracy: 0.6991
# Fold [1/5] - Epoch 2/25 - Train Loss: 0.6280, Train Accuracy: 0.6583, Validation Loss: 0.6106, Validation Accuracy: 0.7040
# Fold [1/5] - Epoch 3/25 - Train Loss: 0.6177, Train Accuracy: 0.6731, Validation Loss: 0.5997, Validation Accuracy: 0.7056
# Fold [1/5] - Epoch 4/25 - Train Loss: 0.6077, Train Accuracy: 0.6849, Validation Loss: 0.5899, Validation Accuracy: 0.7105
# Fold [1/5] - Epoch 5/25 - Train Loss: 0.5964, Train Accuracy: 0.6950, Validation Loss: 0.5808, Validation Accuracy: 0.7159
# Fold [1/5] - Epoch 6/25 - Train Loss: 0.5850, Train Accuracy: 0.7032, Validation Loss: 0.5704, Validation Accuracy: 0.7219
# Fold [1/5] - Epoch 7/25 - Train Loss: 0.5756, Train Accuracy: 0.7110, Validation Loss: 0.5659, Validation Accuracy: 0.7121
# Fold [1/5] - Epoch 8/25 - Train Loss: 0.5644, Train Accuracy: 0.7198, Validation Loss: 0.5562, Validation Accuracy: 0.7116
# Fold [1/5] - Epoch 9/25 - Train Loss: 0.5525, Train Accuracy: 0.7331, Validation Loss: 0.5427, Validation Accuracy: 0.7219
# Fold [1/5] - Epoch 10/25 - Train Loss: 0.5409, Train Accuracy: 0.7392, Validation Loss: 0.5313, Validation Accuracy: 0.7317
# Fold [1/5] - Epoch 11/25 - Train Loss: 0.5294, Train Accuracy: 0.7501, Validation Loss: 0.5194, Validation Accuracy: 0.7414
# Fold [1/5] - Epoch 12/25 - Train Loss: 0.5184, Train Accuracy: 0.7585, Validation Loss: 0.5113, Validation Accuracy: 0.7463
# Fold [1/5] - Epoch 13/25 - Train Loss: 0.5082, Train Accuracy: 0.7654, Validation Loss: 0.5076, Validation Accuracy: 0.7447
# Fold [1/5] - Epoch 14/25 - Train Loss: 0.4965, Train Accuracy: 0.7716, Validation Loss: 0.4953, Validation Accuracy: 0.7637
# Fold [1/5] - Epoch 15/25 - Train Loss: 0.4880, Train Accuracy: 0.7792, Validation Loss: 0.4835, Validation Accuracy: 0.7708
# Fold [1/5] - Epoch 16/25 - Train Loss: 0.4786, Train Accuracy: 0.7866, Validation Loss: 0.4757, Validation Accuracy: 0.7773
# Fold [1/5] - Epoch 17/25 - Train Loss: 0.4692, Train Accuracy: 0.7880, Validation Loss: 0.4818, Validation Accuracy: 0.7626
# Fold [1/5] - Epoch 18/25 - Train Loss: 0.4629, Train Accuracy: 0.7921, Validation Loss: 0.4781, Validation Accuracy: 0.7572
# Fold [1/5] - Epoch 19/25 - Train Loss: 0.4537, Train Accuracy: 0.7975, Validation Loss: 0.4734, Validation Accuracy: 0.7599
# Fold [1/5] - Epoch 20/25 - Train Loss: 0.4441, Train Accuracy: 0.8025, Validation Loss: 0.4578, Validation Accuracy: 0.7784
# Fold [1/5] - Epoch 21/25 - Train Loss: 0.4363, Train Accuracy: 0.8082, Validation Loss: 0.4426, Validation Accuracy: 0.7979
# Fold [1/5] - Epoch 22/25 - Train Loss: 0.4293, Train Accuracy: 0.8142, Validation Loss: 0.4347, Validation Accuracy: 0.8034
# Fold [1/5] - Epoch 23/25 - Train Loss: 0.4222, Train Accuracy: 0.8186, Validation Loss: 0.4293, Validation Accuracy: 0.8007
# Fold [1/5] - Epoch 24/25 - Train Loss: 0.4162, Train Accuracy: 0.8217, Validation Loss: 0.4237, Validation Accuracy: 0.8093
# Fold [1/5] - Epoch 25/25 - Train Loss: 0.4083, Train Accuracy: 0.8274, Validation Loss: 0.4193, Validation Accuracy: 0.8148
# Fold [1/5] - Epoch 1/25 - Train Loss: 0.4074, Train Accuracy: 0.8275, Validation Loss: 0.4068, Validation Accuracy: 0.8110
# Fold [1/5] - Epoch 2/25 - Train Loss: 0.4003, Train Accuracy: 0.8309, Validation Loss: 0.4022, Validation Accuracy: 0.8365
# Fold [1/5] - Epoch 3/25 - Train Loss: 0.3939, Train Accuracy: 0.8368, Validation Loss: 0.3913, Validation Accuracy: 0.8278
# Fold [1/5] - Epoch 4/25 - Train Loss: 0.3861, Train Accuracy: 0.8418, Validation Loss: 0.3866, Validation Accuracy: 0.8408
# Fold [1/5] - Epoch 5/25 - Train Loss: 0.3795, Train Accuracy: 0.8441, Validation Loss: 0.3801, Validation Accuracy: 0.8332
# Fold [1/5] - Epoch 6/25 - Train Loss: 0.3730, Train Accuracy: 0.8453, Validation Loss: 0.3795, Validation Accuracy: 0.8441
# Fold [1/5] - Epoch 7/25 - Train Loss: 0.3721, Train Accuracy: 0.8468, Validation Loss: 0.4277, Validation Accuracy: 0.7887
# Fold [1/5] - Epoch 8/25 - Train Loss: 0.3638, Train Accuracy: 0.8483, Validation Loss: 0.3735, Validation Accuracy: 0.8436
# Fold [1/5] - Epoch 9/25 - Train Loss: 0.3576, Train Accuracy: 0.8524, Validation Loss: 0.3862, Validation Accuracy: 0.8376
# Fold [1/5] - Epoch 10/25 - Train Loss: 0.3544, Train Accuracy: 0.8558, Validation Loss: 0.3691, Validation Accuracy: 0.8430
# Fold [1/5] - Epoch 11/25 - Train Loss: 0.3497, Train Accuracy: 0.8608, Validation Loss: 0.3644, Validation Accuracy: 0.8485
# Fold [1/5] - Epoch 12/25 - Train Loss: 0.3452, Train Accuracy: 0.8604, Validation Loss: 0.3828, Validation Accuracy: 0.8240
# Fold [1/5] - Epoch 13/25 - Train Loss: 0.3415, Train Accuracy: 0.8621, Validation Loss: 0.3708, Validation Accuracy: 0.8343
# Fold [1/5] - Epoch 14/25 - Train Loss: 0.3397, Train Accuracy: 0.8645, Validation Loss: 0.3577, Validation Accuracy: 0.8506
# Fold [1/5] - Epoch 15/25 - Train Loss: 0.3343, Train Accuracy: 0.8654, Validation Loss: 0.3550, Validation Accuracy: 0.8512
# Fold [1/5] - Epoch 16/25 - Train Loss: 0.3285, Train Accuracy: 0.8704, Validation Loss: 0.3538, Validation Accuracy: 0.8490
# Fold [1/5] - Epoch 17/25 - Train Loss: 0.3264, Train Accuracy: 0.8715, Validation Loss: 0.3661, Validation Accuracy: 0.8479
# Fold [1/5] - Epoch 18/25 - Train Loss: 0.3232, Train Accuracy: 0.8734, Validation Loss: 0.3643, Validation Accuracy: 0.8523
# Fold [1/5] - Epoch 19/25 - Train Loss: 0.3192, Train Accuracy: 0.8734, Validation Loss: 0.3455, Validation Accuracy: 0.8561
# Fold [1/5] - Epoch 20/25 - Train Loss: 0.3165, Train Accuracy: 0.8741, Validation Loss: 0.3881, Validation Accuracy: 0.8305
# Fold [1/5] - Epoch 21/25 - Train Loss: 0.3117, Train Accuracy: 0.8770, Validation Loss: 0.3551, Validation Accuracy: 0.8501
# Fold [1/5] - Epoch 22/25 - Train Loss: 0.3141, Train Accuracy: 0.8801, Validation Loss: 0.3506, Validation Accuracy: 0.8555
# Fold [1/5] - Epoch 23/25 - Train Loss: 0.3075, Train Accuracy: 0.8797, Validation Loss: 0.3562, Validation Accuracy: 0.8495
# Fold [1/5] - Epoch 24/25 - Train Loss: 0.3056, Train Accuracy: 0.8828, Validation Loss: 0.3354, Validation Accuracy: 0.8653
# Fold [1/5] - Epoch 25/25 - Train Loss: 0.3004, Train Accuracy: 0.8847, Validation Loss: 0.3486, Validation Accuracy: 0.8571
# Fold [1/5] - Epoch 1/25 - Train Loss: 0.3103, Train Accuracy: 0.8752, Validation Loss: 0.2993, Validation Accuracy: 0.8832
# Fold [1/5] - Epoch 2/25 - Train Loss: 0.3052, Train Accuracy: 0.8786, Validation Loss: 0.3199, Validation Accuracy: 0.8756
# Fold [1/5] - Epoch 3/25 - Train Loss: 0.3004, Train Accuracy: 0.8789, Validation Loss: 0.2975, Validation Accuracy: 0.8930
# Fold [1/5] - Epoch 4/25 - Train Loss: 0.3025, Train Accuracy: 0.8843, Validation Loss: 0.2998, Validation Accuracy: 0.8892
# Fold [1/5] - Epoch 5/25 - Train Loss: 0.2946, Train Accuracy: 0.8839, Validation Loss: 0.3512, Validation Accuracy: 0.8577
# Fold [1/5] - Epoch 6/25 - Train Loss: 0.2903, Train Accuracy: 0.8877, Validation Loss: 0.2965, Validation Accuracy: 0.8914
# Fold [1/5] - Epoch 7/25 - Train Loss: 0.2875, Train Accuracy: 0.8890, Validation Loss: 0.3009, Validation Accuracy: 0.8886
# Fold [1/5] - Epoch 8/25 - Train Loss: 0.2852, Train Accuracy: 0.8897, Validation Loss: 0.3525, Validation Accuracy: 0.8322
# Fold [1/5] - Epoch 9/25 - Train Loss: 0.2851, Train Accuracy: 0.8892, Validation Loss: 0.3091, Validation Accuracy: 0.8713
# Fold [1/5] - Epoch 10/25 - Train Loss: 0.2804, Train Accuracy: 0.8952, Validation Loss: 0.3102, Validation Accuracy: 0.8848
# Fold [1/5] - Epoch 11/25 - Train Loss: 0.2777, Train Accuracy: 0.8949, Validation Loss: 0.3031, Validation Accuracy: 0.8734
# Fold [1/5] - Epoch 12/25 - Train Loss: 0.2748, Train Accuracy: 0.8949, Validation Loss: 0.2917, Validation Accuracy: 0.8892
# Fold [1/5] - Epoch 13/25 - Train Loss: 0.2744, Train Accuracy: 0.8971, Validation Loss: 0.3173, Validation Accuracy: 0.8588
# Fold [1/5] - Epoch 14/25 - Train Loss: 0.2717, Train Accuracy: 0.8960, Validation Loss: 0.2979, Validation Accuracy: 0.8810
# Fold [1/5] - Epoch 15/25 - Train Loss: 0.2684, Train Accuracy: 0.8965, Validation Loss: 0.2942, Validation Accuracy: 0.8805
# Fold [1/5] - Epoch 16/25 - Train Loss: 0.2646, Train Accuracy: 0.8983, Validation Loss: 0.2966, Validation Accuracy: 0.8778
# Fold [1/5] - Epoch 17/25 - Train Loss: 0.2648, Train Accuracy: 0.9009, Validation Loss: 0.3219, Validation Accuracy: 0.8800
# Fold [1/5] - Epoch 18/25 - Train Loss: 0.2599, Train Accuracy: 0.9015, Validation Loss: 0.3077, Validation Accuracy: 0.8859
# Fold [1/5] - Epoch 19/25 - Train Loss: 0.2586, Train Accuracy: 0.9018, Validation Loss: 0.3248, Validation Accuracy: 0.8729
# Fold [1/5] - Epoch 20/25 - Train Loss: 0.2566, Train Accuracy: 0.9021, Validation Loss: 0.2960, Validation Accuracy: 0.8865
# Fold [1/5] - Epoch 21/25 - Train Loss: 0.2548, Train Accuracy: 0.8998, Validation Loss: 0.3182, Validation Accuracy: 0.8805
# Fold [1/5] - Epoch 22/25 - Train Loss: 0.2543, Train Accuracy: 0.9062, Validation Loss: 0.4170, Validation Accuracy: 0.8278
# Fold [1/5] - Epoch 23/25 - Train Loss: 0.2517, Train Accuracy: 0.9064, Validation Loss: 0.3760, Validation Accuracy: 0.8517
# Fold [1/5] - Epoch 24/25 - Train Loss: 0.2486, Train Accuracy: 0.9030, Validation Loss: 0.3809, Validation Accuracy: 0.8463
# Fold [1/5] - Epoch 25/25 - Train Loss: 0.2489, Train Accuracy: 0.9076, Validation Loss: 0.2906, Validation Accuracy: 0.8767
# Fold [1/5] - Epoch 1/25 - Train Loss: 0.2567, Train Accuracy: 0.9025, Validation Loss: 0.3274, Validation Accuracy: 0.8565
# Fold [1/5] - Epoch 2/25 - Train Loss: 0.2537, Train Accuracy: 0.9022, Validation Loss: 0.2599, Validation Accuracy: 0.9005
# Fold [1/5] - Epoch 3/25 - Train Loss: 0.2485, Train Accuracy: 0.9047, Validation Loss: 0.2533, Validation Accuracy: 0.9005
# Fold [1/5] - Epoch 4/25 - Train Loss: 0.2497, Train Accuracy: 0.9049, Validation Loss: 0.5284, Validation Accuracy: 0.7489
# Warning: Model might be overfitting. Gap: 0.1560
# Fold [1/5] - Epoch 5/25 - Train Loss: 0.2439, Train Accuracy: 0.9067, Validation Loss: 0.2488, Validation Accuracy: 0.9011
# Fold [1/5] - Epoch 6/25 - Train Loss: 0.2404, Train Accuracy: 0.9083, Validation Loss: 0.3189, Validation Accuracy: 0.8538
# Fold [1/5] - Epoch 7/25 - Train Loss: 0.2399, Train Accuracy: 0.9082, Validation Loss: 0.2490, Validation Accuracy: 0.9022
# Fold [1/5] - Epoch 8/25 - Train Loss: 0.2359, Train Accuracy: 0.9079, Validation Loss: 0.2527, Validation Accuracy: 0.8984
# Fold [1/5] - Epoch 9/25 - Train Loss: 0.2353, Train Accuracy: 0.9100, Validation Loss: 0.2543, Validation Accuracy: 0.9011
# Fold [1/5] - Epoch 10/25 - Train Loss: 0.2331, Train Accuracy: 0.9085, Validation Loss: 0.2562, Validation Accuracy: 0.9011
# Fold [1/5] - Epoch 11/25 - Train Loss: 0.2304, Train Accuracy: 0.9127, Validation Loss: 0.3204, Validation Accuracy: 0.8587
# Fold [1/5] - Epoch 12/25 - Train Loss: 0.2287, Train Accuracy: 0.9162, Validation Loss: 0.2488, Validation Accuracy: 0.9016
# Fold [1/5] - Epoch 13/25 - Train Loss: 0.2269, Train Accuracy: 0.9136, Validation Loss: 0.2910, Validation Accuracy: 0.8739
# Fold [1/5] - Epoch 14/25 - Train Loss: 0.2244, Train Accuracy: 0.9136, Validation Loss: 0.2510, Validation Accuracy: 0.8989
# Fold [1/5] - Epoch 15/25 - Train Loss: 0.2234, Train Accuracy: 0.9180, Validation Loss: 0.3943, Validation Accuracy: 0.8250
# Fold [1/5] - Epoch 16/25 - Train Loss: 0.2220, Train Accuracy: 0.9183, Validation Loss: 0.2553, Validation Accuracy: 0.8973
# Fold [1/5] - Epoch 17/25 - Train Loss: 0.2179, Train Accuracy: 0.9191, Validation Loss: 0.2482, Validation Accuracy: 0.9000
# Fold [1/5] - Epoch 18/25 - Train Loss: 0.2179, Train Accuracy: 0.9188, Validation Loss: 0.3217, Validation Accuracy: 0.8625
# Fold [1/5] - Epoch 19/25 - Train Loss: 0.2156, Train Accuracy: 0.9211, Validation Loss: 0.3726, Validation Accuracy: 0.8293
# Fold [1/5] - Epoch 20/25 - Train Loss: 0.2129, Train Accuracy: 0.9208, Validation Loss: 0.2816, Validation Accuracy: 0.8837
# Fold [1/5] - Epoch 21/25 - Train Loss: 0.2144, Train Accuracy: 0.9197, Validation Loss: 0.2526, Validation Accuracy: 0.9000
# Fold [1/5] - Epoch 22/25 - Train Loss: 0.2090, Train Accuracy: 0.9248, Validation Loss: 0.3107, Validation Accuracy: 0.8701
# Fold [1/5] - Epoch 23/25 - Train Loss: 0.2071, Train Accuracy: 0.9222, Validation Loss: 0.2525, Validation Accuracy: 0.8951
# Fold [1/5] - Epoch 24/25 - Train Loss: 0.2037, Train Accuracy: 0.9267, Validation Loss: 0.2631, Validation Accuracy: 0.8902
# Fold [1/5] - Epoch 25/25 - Train Loss: 0.2026, Train Accuracy: 0.9244, Validation Loss: 0.2535, Validation Accuracy: 0.8951
# Training for enzyme class 3
# Fold [1842/5] - Epoch 1/25 - Train Loss: 0.6476, Train Accuracy: 0.7144, Validation Loss: 0.6239, Validation Accuracy: 0.7045
# Fold [1842/5] - Epoch 2/25 - Train Loss: 0.6094, Train Accuracy: 0.7144, Validation Loss: 0.6104, Validation Accuracy: 0.7045
# Fold [1842/5] - Epoch 3/25 - Train Loss: 0.5995, Train Accuracy: 0.7144, Validation Loss: 0.6073, Validation Accuracy: 0.7045
# Fold [1842/5] - Epoch 4/25 - Train Loss: 0.5985, Train Accuracy: 0.7144, Validation Loss: 0.6057, Validation Accuracy: 0.7045
# Fold [1842/5] - Epoch 5/25 - Train Loss: 0.5968, Train Accuracy: 0.7144, Validation Loss: 0.6065, Validation Accuracy: 0.7045
# Fold [1842/5] - Epoch 6/25 - Train Loss: 0.5977, Train Accuracy: 0.7144, Validation Loss: 0.6055, Validation Accuracy: 0.7045
# Fold [1842/5] - Epoch 7/25 - Train Loss: 0.5963, Train Accuracy: 0.7144, Validation Loss: 0.6071, Validation Accuracy: 0.7045
# Fold [1842/5] - Epoch 8/25 - Train Loss: 0.5973, Train Accuracy: 0.7144, Validation Loss: 0.6065, Validation Accuracy: 0.7045
# Fold [1842/5] - Epoch 9/25 - Train Loss: 0.5995, Train Accuracy: 0.7144, Validation Loss: 0.6062, Validation Accuracy: 0.7045
# Fold [1842/5] - Epoch 10/25 - Train Loss: 0.5957, Train Accuracy: 0.7144, Validation Loss: 0.6051, Validation Accuracy: 0.7045
# Fold [1842/5] - Epoch 11/25 - Train Loss: 0.5954, Train Accuracy: 0.7144, Validation Loss: 0.6054, Validation Accuracy: 0.7045
# Fold [1842/5] - Epoch 12/25 - Train Loss: 0.5951, Train Accuracy: 0.7144, Validation Loss: 0.6056, Validation Accuracy: 0.7045
# Fold [1842/5] - Epoch 13/25 - Train Loss: 0.5961, Train Accuracy: 0.7144, Validation Loss: 0.6048, Validation Accuracy: 0.7045
# Fold [1842/5] - Epoch 14/25 - Train Loss: 0.5970, Train Accuracy: 0.7144, Validation Loss: 0.6044, Validation Accuracy: 0.7045
# Fold [1842/5] - Epoch 15/25 - Train Loss: 0.5966, Train Accuracy: 0.7144, Validation Loss: 0.6031, Validation Accuracy: 0.7045
# Fold [1842/5] - Epoch 16/25 - Train Loss: 0.5962, Train Accuracy: 0.7144, Validation Loss: 0.6027, Validation Accuracy: 0.7045
# Fold [1842/5] - Epoch 17/25 - Train Loss: 0.5934, Train Accuracy: 0.7144, Validation Loss: 0.6015, Validation Accuracy: 0.7045
# Fold [1842/5] - Epoch 18/25 - Train Loss: 0.5941, Train Accuracy: 0.7144, Validation Loss: 0.6027, Validation Accuracy: 0.7045
# Fold [1842/5] - Epoch 19/25 - Train Loss: 0.5923, Train Accuracy: 0.7144, Validation Loss: 0.6018, Validation Accuracy: 0.7045
# Fold [1842/5] - Epoch 20/25 - Train Loss: 0.5929, Train Accuracy: 0.7144, Validation Loss: 0.6007, Validation Accuracy: 0.7045
# Fold [1842/5] - Epoch 21/25 - Train Loss: 0.5922, Train Accuracy: 0.7144, Validation Loss: 0.6010, Validation Accuracy: 0.7045
# Fold [1842/5] - Epoch 22/25 - Train Loss: 0.5927, Train Accuracy: 0.7144, Validation Loss: 0.5991, Validation Accuracy: 0.7045
# Fold [1842/5] - Epoch 23/25 - Train Loss: 0.5930, Train Accuracy: 0.7144, Validation Loss: 0.5997, Validation Accuracy: 0.7045
# Fold [1842/5] - Epoch 24/25 - Train Loss: 0.5895, Train Accuracy: 0.7144, Validation Loss: 0.5978, Validation Accuracy: 0.7045
# Fold [1842/5] - Epoch 25/25 - Train Loss: 0.5871, Train Accuracy: 0.7144, Validation Loss: 0.5970, Validation Accuracy: 0.7045
# Fold [1/5] - Epoch 1/25 - Train Loss: 0.5782, Train Accuracy: 0.7274, Validation Loss: 0.6418, Validation Accuracy: 0.6524
# Fold [1/5] - Epoch 2/25 - Train Loss: 0.5755, Train Accuracy: 0.7274, Validation Loss: 0.6405, Validation Accuracy: 0.6524
# Fold [1/5] - Epoch 3/25 - Train Loss: 0.5726, Train Accuracy: 0.7274, Validation Loss: 0.6396, Validation Accuracy: 0.6524
# Fold [1/5] - Epoch 4/25 - Train Loss: 0.5718, Train Accuracy: 0.7274, Validation Loss: 0.6369, Validation Accuracy: 0.6524
# Fold [1/5] - Epoch 5/25 - Train Loss: 0.5673, Train Accuracy: 0.7274, Validation Loss: 0.6344, Validation Accuracy: 0.6524
# Fold [1/5] - Epoch 6/25 - Train Loss: 0.5674, Train Accuracy: 0.7274, Validation Loss: 0.6276, Validation Accuracy: 0.6524
# Fold [1/5] - Epoch 7/25 - Train Loss: 0.5630, Train Accuracy: 0.7274, Validation Loss: 0.6254, Validation Accuracy: 0.6524
# Fold [1/5] - Epoch 8/25 - Train Loss: 0.5596, Train Accuracy: 0.7274, Validation Loss: 0.6197, Validation Accuracy: 0.6524
# Fold [1/5] - Epoch 9/25 - Train Loss: 0.5546, Train Accuracy: 0.7274, Validation Loss: 0.6160, Validation Accuracy: 0.6524
# Fold [1/5] - Epoch 10/25 - Train Loss: 0.5498, Train Accuracy: 0.7274, Validation Loss: 0.6087, Validation Accuracy: 0.6524
# Fold [1/5] - Epoch 11/25 - Train Loss: 0.5464, Train Accuracy: 0.7274, Validation Loss: 0.5990, Validation Accuracy: 0.6524
# Fold [1/5] - Epoch 12/25 - Train Loss: 0.5385, Train Accuracy: 0.7274, Validation Loss: 0.5969, Validation Accuracy: 0.6524
# Fold [1/5] - Epoch 13/25 - Train Loss: 0.5330, Train Accuracy: 0.7274, Validation Loss: 0.5856, Validation Accuracy: 0.6524
# Fold [1/5] - Epoch 14/25 - Train Loss: 0.5240, Train Accuracy: 0.7274, Validation Loss: 0.5724, Validation Accuracy: 0.6524
# Fold [1/5] - Epoch 15/25 - Train Loss: 0.5174, Train Accuracy: 0.7274, Validation Loss: 0.5665, Validation Accuracy: 0.6524
# Fold [1/5] - Epoch 16/25 - Train Loss: 0.5090, Train Accuracy: 0.7278, Validation Loss: 0.5523, Validation Accuracy: 0.6540
# Fold [1/5] - Epoch 17/25 - Train Loss: 0.4985, Train Accuracy: 0.7335, Validation Loss: 0.5460, Validation Accuracy: 0.6697
# Fold [1/5] - Epoch 18/25 - Train Loss: 0.4866, Train Accuracy: 0.7490, Validation Loss: 0.5288, Validation Accuracy: 0.7159
# Fold [1/5] - Epoch 19/25 - Train Loss: 0.4758, Train Accuracy: 0.7623, Validation Loss: 0.5228, Validation Accuracy: 0.7175
# Fold [1/5] - Epoch 20/25 - Train Loss: 0.4657, Train Accuracy: 0.7712, Validation Loss: 0.5038, Validation Accuracy: 0.7670
# Fold [1/5] - Epoch 21/25 - Train Loss: 0.4523, Train Accuracy: 0.7845, Validation Loss: 0.4930, Validation Accuracy: 0.7719
# Fold [1/5] - Epoch 22/25 - Train Loss: 0.4399, Train Accuracy: 0.7918, Validation Loss: 0.4815, Validation Accuracy: 0.7865
# Fold [1/5] - Epoch 23/25 - Train Loss: 0.4261, Train Accuracy: 0.8055, Validation Loss: 0.4797, Validation Accuracy: 0.7691
# Fold [1/5] - Epoch 24/25 - Train Loss: 0.4136, Train Accuracy: 0.8137, Validation Loss: 0.4654, Validation Accuracy: 0.7844
# Fold [1/5] - Epoch 25/25 - Train Loss: 0.4037, Train Accuracy: 0.8229, Validation Loss: 0.4537, Validation Accuracy: 0.7941
# Fold [1/5] - Epoch 1/25 - Train Loss: 0.4043, Train Accuracy: 0.8262, Validation Loss: 0.3873, Validation Accuracy: 0.8528
# Fold [1/5] - Epoch 2/25 - Train Loss: 0.3928, Train Accuracy: 0.8312, Validation Loss: 0.3760, Validation Accuracy: 0.8452
# Fold [1/5] - Epoch 3/25 - Train Loss: 0.3826, Train Accuracy: 0.8389, Validation Loss: 0.3702, Validation Accuracy: 0.8604
# Fold [1/5] - Epoch 4/25 - Train Loss: 0.3717, Train Accuracy: 0.8468, Validation Loss: 0.3611, Validation Accuracy: 0.8615
# Fold [1/5] - Epoch 5/25 - Train Loss: 0.3640, Train Accuracy: 0.8526, Validation Loss: 0.3693, Validation Accuracy: 0.8702
# Fold [1/5] - Epoch 6/25 - Train Loss: 0.3537, Train Accuracy: 0.8597, Validation Loss: 0.3481, Validation Accuracy: 0.8647
# Fold [1/5] - Epoch 7/25 - Train Loss: 0.3477, Train Accuracy: 0.8634, Validation Loss: 0.3563, Validation Accuracy: 0.8734
# Fold [1/5] - Epoch 8/25 - Train Loss: 0.3384, Train Accuracy: 0.8658, Validation Loss: 0.3408, Validation Accuracy: 0.8696
# Fold [1/5] - Epoch 9/25 - Train Loss: 0.3331, Train Accuracy: 0.8680, Validation Loss: 0.3467, Validation Accuracy: 0.8762
# Fold [1/5] - Epoch 10/25 - Train Loss: 0.3256, Train Accuracy: 0.8731, Validation Loss: 0.3307, Validation Accuracy: 0.8783
# Fold [1/5] - Epoch 11/25 - Train Loss: 0.3198, Train Accuracy: 0.8755, Validation Loss: 0.3485, Validation Accuracy: 0.8539
# Fold [1/5] - Epoch 12/25 - Train Loss: 0.3194, Train Accuracy: 0.8793, Validation Loss: 0.3220, Validation Accuracy: 0.8843
# Fold [1/5] - Epoch 13/25 - Train Loss: 0.3085, Train Accuracy: 0.8852, Validation Loss: 0.3185, Validation Accuracy: 0.8800
# Fold [1/5] - Epoch 14/25 - Train Loss: 0.3034, Train Accuracy: 0.8856, Validation Loss: 0.3176, Validation Accuracy: 0.8789
# Fold [1/5] - Epoch 15/25 - Train Loss: 0.3011, Train Accuracy: 0.8861, Validation Loss: 0.3294, Validation Accuracy: 0.8702
# Fold [1/5] - Epoch 16/25 - Train Loss: 0.2953, Train Accuracy: 0.8903, Validation Loss: 0.3274, Validation Accuracy: 0.8691
# Fold [1/5] - Epoch 17/25 - Train Loss: 0.2901, Train Accuracy: 0.8913, Validation Loss: 0.3097, Validation Accuracy: 0.8816
# Fold [1/5] - Epoch 18/25 - Train Loss: 0.2853, Train Accuracy: 0.8933, Validation Loss: 0.3093, Validation Accuracy: 0.8810
# Fold [1/5] - Epoch 19/25 - Train Loss: 0.2867, Train Accuracy: 0.8931, Validation Loss: 0.3294, Validation Accuracy: 0.8724
# Fold [1/5] - Epoch 20/25 - Train Loss: 0.2780, Train Accuracy: 0.8957, Validation Loss: 0.2966, Validation Accuracy: 0.8924
# Fold [1/5] - Epoch 21/25 - Train Loss: 0.2737, Train Accuracy: 0.8953, Validation Loss: 0.2962, Validation Accuracy: 0.8919
# Fold [1/5] - Epoch 22/25 - Train Loss: 0.2706, Train Accuracy: 0.9000, Validation Loss: 0.2942, Validation Accuracy: 0.8935
# Fold [1/5] - Epoch 23/25 - Train Loss: 0.2671, Train Accuracy: 0.8976, Validation Loss: 0.3119, Validation Accuracy: 0.8767
# Fold [1/5] - Epoch 24/25 - Train Loss: 0.2643, Train Accuracy: 0.9025, Validation Loss: 0.2957, Validation Accuracy: 0.8881
# Fold [1/5] - Epoch 25/25 - Train Loss: 0.2603, Train Accuracy: 0.9033, Validation Loss: 0.3124, Validation Accuracy: 0.8756
# Fold [1/5] - Epoch 1/25 - Train Loss: 0.2725, Train Accuracy: 0.8976, Validation Loss: 0.2353, Validation Accuracy: 0.9011
# Fold [1/5] - Epoch 2/25 - Train Loss: 0.2688, Train Accuracy: 0.9013, Validation Loss: 0.2805, Validation Accuracy: 0.8892
# Fold [1/5] - Epoch 3/25 - Train Loss: 0.2664, Train Accuracy: 0.9014, Validation Loss: 0.2583, Validation Accuracy: 0.8843
# Fold [1/5] - Epoch 4/25 - Train Loss: 0.2662, Train Accuracy: 0.9029, Validation Loss: 0.3372, Validation Accuracy: 0.8588
# Fold [1/5] - Epoch 5/25 - Train Loss: 0.2575, Train Accuracy: 0.9045, Validation Loss: 0.2299, Validation Accuracy: 0.9087
# Fold [1/5] - Epoch 6/25 - Train Loss: 0.2607, Train Accuracy: 0.9059, Validation Loss: 0.4049, Validation Accuracy: 0.8191
# Fold [1/5] - Epoch 7/25 - Train Loss: 0.2525, Train Accuracy: 0.9062, Validation Loss: 0.2248, Validation Accuracy: 0.9180
# Fold [1/5] - Epoch 8/25 - Train Loss: 0.2514, Train Accuracy: 0.9067, Validation Loss: 0.2632, Validation Accuracy: 0.8838
# Fold [1/5] - Epoch 9/25 - Train Loss: 0.2462, Train Accuracy: 0.9063, Validation Loss: 0.2233, Validation Accuracy: 0.9185
# Fold [1/5] - Epoch 10/25 - Train Loss: 0.2441, Train Accuracy: 0.9104, Validation Loss: 0.2465, Validation Accuracy: 0.8935
# Fold [1/5] - Epoch 11/25 - Train Loss: 0.2406, Train Accuracy: 0.9104, Validation Loss: 0.2218, Validation Accuracy: 0.9218
# Fold [1/5] - Epoch 12/25 - Train Loss: 0.2428, Train Accuracy: 0.9095, Validation Loss: 0.3755, Validation Accuracy: 0.8332
# Fold [1/5] - Epoch 13/25 - Train Loss: 0.2360, Train Accuracy: 0.9136, Validation Loss: 0.2224, Validation Accuracy: 0.9142
# Fold [1/5] - Epoch 14/25 - Train Loss: 0.2338, Train Accuracy: 0.9119, Validation Loss: 0.2275, Validation Accuracy: 0.9098
# Fold [1/5] - Epoch 15/25 - Train Loss: 0.2303, Train Accuracy: 0.9134, Validation Loss: 0.2192, Validation Accuracy: 0.9185
# Fold [1/5] - Epoch 16/25 - Train Loss: 0.2307, Train Accuracy: 0.9153, Validation Loss: 0.2567, Validation Accuracy: 0.8924
# Fold [1/5] - Epoch 17/25 - Train Loss: 0.2271, Train Accuracy: 0.9155, Validation Loss: 0.2233, Validation Accuracy: 0.9120
# Fold [1/5] - Epoch 18/25 - Train Loss: 0.2251, Train Accuracy: 0.9167, Validation Loss: 0.2361, Validation Accuracy: 0.8995
# Fold [1/5] - Epoch 19/25 - Train Loss: 0.2235, Train Accuracy: 0.9176, Validation Loss: 0.2214, Validation Accuracy: 0.9158
# Fold [1/5] - Epoch 20/25 - Train Loss: 0.2202, Train Accuracy: 0.9177, Validation Loss: 0.2537, Validation Accuracy: 0.8897
# Fold [1/5] - Epoch 21/25 - Train Loss: 0.2233, Train Accuracy: 0.9193, Validation Loss: 0.2808, Validation Accuracy: 0.8789
# Fold [1/5] - Epoch 22/25 - Train Loss: 0.2175, Train Accuracy: 0.9207, Validation Loss: 0.2200, Validation Accuracy: 0.9185
# Fold [1/5] - Epoch 23/25 - Train Loss: 0.2146, Train Accuracy: 0.9205, Validation Loss: 0.2240, Validation Accuracy: 0.9163
# Fold [1/5] - Epoch 24/25 - Train Loss: 0.2128, Train Accuracy: 0.9226, Validation Loss: 0.2146, Validation Accuracy: 0.9169
# Fold [1/5] - Epoch 25/25 - Train Loss: 0.2102, Train Accuracy: 0.9222, Validation Loss: 0.2138, Validation Accuracy: 0.9180
# Fold [1/5] - Epoch 1/25 - Train Loss: 0.2116, Train Accuracy: 0.9234, Validation Loss: 0.2220, Validation Accuracy: 0.9109
# Fold [1/5] - Epoch 2/25 - Train Loss: 0.2074, Train Accuracy: 0.9229, Validation Loss: 0.2106, Validation Accuracy: 0.9310
# Fold [1/5] - Epoch 3/25 - Train Loss: 0.2053, Train Accuracy: 0.9231, Validation Loss: 0.2135, Validation Accuracy: 0.9179
# Fold [1/5] - Epoch 4/25 - Train Loss: 0.2035, Train Accuracy: 0.9261, Validation Loss: 0.2217, Validation Accuracy: 0.9125
# Fold [1/5] - Epoch 5/25 - Train Loss: 0.2004, Train Accuracy: 0.9260, Validation Loss: 0.2094, Validation Accuracy: 0.9190
# Fold [1/5] - Epoch 6/25 - Train Loss: 0.1981, Train Accuracy: 0.9272, Validation Loss: 0.2083, Validation Accuracy: 0.9207
# Fold [1/5] - Epoch 7/25 - Train Loss: 0.1969, Train Accuracy: 0.9272, Validation Loss: 0.2093, Validation Accuracy: 0.9196
# Fold [1/5] - Epoch 8/25 - Train Loss: 0.1949, Train Accuracy: 0.9290, Validation Loss: 0.2819, Validation Accuracy: 0.8815
# Fold [1/5] - Epoch 9/25 - Train Loss: 0.1924, Train Accuracy: 0.9309, Validation Loss: 0.2118, Validation Accuracy: 0.9179
# Fold [1/5] - Epoch 10/25 - Train Loss: 0.1938, Train Accuracy: 0.9295, Validation Loss: 0.2950, Validation Accuracy: 0.8712
# Fold [1/5] - Epoch 11/25 - Train Loss: 0.1887, Train Accuracy: 0.9312, Validation Loss: 0.2100, Validation Accuracy: 0.9255
# Fold [1/5] - Epoch 12/25 - Train Loss: 0.1877, Train Accuracy: 0.9324, Validation Loss: 0.2099, Validation Accuracy: 0.9196
# Fold [1/5] - Epoch 13/25 - Train Loss: 0.1844, Train Accuracy: 0.9360, Validation Loss: 0.2100, Validation Accuracy: 0.9217
# Fold [1/5] - Epoch 14/25 - Train Loss: 0.1839, Train Accuracy: 0.9328, Validation Loss: 0.2131, Validation Accuracy: 0.9174
# Fold [1/5] - Epoch 15/25 - Train Loss: 0.1841, Train Accuracy: 0.9347, Validation Loss: 0.2933, Validation Accuracy: 0.8772
# Fold [1/5] - Epoch 16/25 - Train Loss: 0.1805, Train Accuracy: 0.9362, Validation Loss: 0.2229, Validation Accuracy: 0.9212
# Fold [1/5] - Epoch 17/25 - Train Loss: 0.1790, Train Accuracy: 0.9348, Validation Loss: 0.2164, Validation Accuracy: 0.9136
# Fold [1/5] - Epoch 18/25 - Train Loss: 0.1803, Train Accuracy: 0.9370, Validation Loss: 0.2368, Validation Accuracy: 0.9098
# Fold [1/5] - Epoch 19/25 - Train Loss: 0.1757, Train Accuracy: 0.9366, Validation Loss: 0.2275, Validation Accuracy: 0.9163
# Fold [1/5] - Epoch 20/25 - Train Loss: 0.1743, Train Accuracy: 0.9377, Validation Loss: 0.2073, Validation Accuracy: 0.9212
# Fold [1/5] - Epoch 21/25 - Train Loss: 0.1722, Train Accuracy: 0.9408, Validation Loss: 0.2089, Validation Accuracy: 0.9201
# Fold [1/5] - Epoch 22/25 - Train Loss: 0.1712, Train Accuracy: 0.9394, Validation Loss: 0.2110, Validation Accuracy: 0.9185
# Fold [1/5] - Epoch 23/25 - Train Loss: 0.1688, Train Accuracy: 0.9412, Validation Loss: 0.2109, Validation Accuracy: 0.9185
# Fold [1/5] - Epoch 24/25 - Train Loss: 0.1676, Train Accuracy: 0.9419, Validation Loss: 0.2157, Validation Accuracy: 0.9087
# Fold [1/5] - Epoch 25/25 - Train Loss: 0.1670, Train Accuracy: 0.9411, Validation Loss: 0.2087, Validation Accuracy: 0.9196
# Training for enzyme class 4
# Fold [1842/5] - Epoch 1/25 - Train Loss: 0.5152, Train Accuracy: 0.9002, Validation Loss: 0.4033, Validation Accuracy: 0.9115
# Fold [1842/5] - Epoch 2/25 - Train Loss: 0.3195, Train Accuracy: 0.9341, Validation Loss: 0.3162, Validation Accuracy: 0.9115
# Fold [1842/5] - Epoch 3/25 - Train Loss: 0.2614, Train Accuracy: 0.9341, Validation Loss: 0.3016, Validation Accuracy: 0.9115
# Fold [1842/5] - Epoch 4/25 - Train Loss: 0.2464, Train Accuracy: 0.9341, Validation Loss: 0.3006, Validation Accuracy: 0.9115
# Fold [1842/5] - Epoch 5/25 - Train Loss: 0.2426, Train Accuracy: 0.9341, Validation Loss: 0.2995, Validation Accuracy: 0.9115
# Fold [1842/5] - Epoch 6/25 - Train Loss: 0.2417, Train Accuracy: 0.9341, Validation Loss: 0.3016, Validation Accuracy: 0.9115
# Fold [1842/5] - Epoch 7/25 - Train Loss: 0.2413, Train Accuracy: 0.9341, Validation Loss: 0.3007, Validation Accuracy: 0.9115
# Fold [1842/5] - Epoch 8/25 - Train Loss: 0.2445, Train Accuracy: 0.9341, Validation Loss: 0.2993, Validation Accuracy: 0.9115
# Fold [1842/5] - Epoch 9/25 - Train Loss: 0.2408, Train Accuracy: 0.9341, Validation Loss: 0.3042, Validation Accuracy: 0.9115
# ...
# Fold [1/5] - Epoch 23/25 - Train Loss: 0.0578, Train Accuracy: 0.9822, Validation Loss: 0.0519, Validation Accuracy: 0.9842
# Fold [1/5] - Epoch 24/25 - Train Loss: 0.0562, Train Accuracy: 0.9829, Validation Loss: 0.0512, Validation Accuracy: 0.9821
# Fold [1/5] - Epoch 25/25 - Train Loss: 0.0558, Train Accuracy: 0.9823, Validation Loss: 0.0505, Validation Accuracy: 0.9826
# Training for enzyme class 7
# Fold [1842/5] - Epoch 1/25 - Train Loss: 0.4679, Train Accuracy: 0.9762, Validation Loss: 0.2973, Validation Accuracy: 0.9891
# Fold [1842/5] - Epoch 2/25 - Train Loss: 0.2309, Train Accuracy: 0.9769, Validation Loss: 0.1502, Validation Accuracy: 0.9891
# Fold [1842/5] - Epoch 3/25 - Train Loss: 0.1475, Train Accuracy: 0.9769, Validation Loss: 0.0991, Validation Accuracy: 0.9891
# Fold [1842/5] - Epoch 4/25 - Train Loss: 0.1207, Train Accuracy: 0.9769, Validation Loss: 0.0785, Validation Accuracy: 0.9891
# Fold [1842/5] - Epoch 5/25 - Train Loss: 0.1118, Train Accuracy: 0.9769, Validation Loss: 0.0704, Validation Accuracy: 0.9891
# Fold [1842/5] - Epoch 6/25 - Train Loss: 0.1084, Train Accuracy: 0.9769, Validation Loss: 0.0666, Validation Accuracy: 0.9891
# Fold [1842/5] - Epoch 7/25 - Train Loss: 0.1068, Train Accuracy: 0.9769, Validation Loss: 0.0645, Validation Accuracy: 0.9891
# Fold [1842/5] - Epoch 8/25 - Train Loss: 0.1058, Train Accuracy: 0.9769, Validation Loss: 0.0650, Validation Accuracy: 0.9891
# Fold [1842/5] - Epoch 9/25 - Train Loss: 0.1050, Train Accuracy: 0.9769, Validation Loss: 0.0642, Validation Accuracy: 0.9891
# Fold [1842/5] - Epoch 10/25 - Train Loss: 0.1044, Train Accuracy: 0.9769, Validation Loss: 0.0618, Validation Accuracy: 0.9891
# Fold [1842/5] - Epoch 11/25 - Train Loss: 0.1037, Train Accuracy: 0.9769, Validation Loss: 0.0613, Validation Accuracy: 0.9891
# Fold [1842/5] - Epoch 12/25 - Train Loss: 0.1030, Train Accuracy: 0.9769, Validation Loss: 0.0622, Validation Accuracy: 0.9891
# Fold [1842/5] - Epoch 13/25 - Train Loss: 0.1024, Train Accuracy: 0.9769, Validation Loss: 0.0606, Validation Accuracy: 0.9891
# Fold [1842/5] - Epoch 14/25 - Train Loss: 0.1017, Train Accuracy: 0.9769, Validation Loss: 0.0602, Validation Accuracy: 0.9891
# Fold [1842/5] - Epoch 15/25 - Train Loss: 0.1010, Train Accuracy: 0.9769, Validation Loss: 0.0598, Validation Accuracy: 0.9891
# Fold [1842/5] - Epoch 16/25 - Train Loss: 0.1004, Train Accuracy: 0.9769, Validation Loss: 0.0594, Validation Accuracy: 0.9891
# Fold [1842/5] - Epoch 17/25 - Train Loss: 0.0997, Train Accuracy: 0.9769, Validation Loss: 0.0591, Validation Accuracy: 0.9891
# Fold [1842/5] - Epoch 18/25 - Train Loss: 0.0990, Train Accuracy: 0.9769, Validation Loss: 0.0587, Validation Accuracy: 0.9891
# Fold [1842/5] - Epoch 19/25 - Train Loss: 0.0983, Train Accuracy: 0.9769, Validation Loss: 0.0584, Validation Accuracy: 0.9891
# Fold [1842/5] - Epoch 20/25 - Train Loss: 0.0976, Train Accuracy: 0.9769, Validation Loss: 0.0581, Validation Accuracy: 0.9891
# Fold [1842/5] - Epoch 21/25 - Train Loss: 0.0968, Train Accuracy: 0.9769, Validation Loss: 0.0577, Validation Accuracy: 0.9891
# Fold [1842/5] - Epoch 22/25 - Train Loss: 0.0960, Train Accuracy: 0.9769, Validation Loss: 0.0574, Validation Accuracy: 0.9891
# Fold [1842/5] - Epoch 23/25 - Train Loss: 0.0952, Train Accuracy: 0.9769, Validation Loss: 0.0570, Validation Accuracy: 0.9891
# Fold [1842/5] - Epoch 24/25 - Train Loss: 0.0944, Train Accuracy: 0.9769, Validation Loss: 0.0566, Validation Accuracy: 0.9891
# Fold [1842/5] - Epoch 25/25 - Train Loss: 0.0935, Train Accuracy: 0.9769, Validation Loss: 0.0562, Validation Accuracy: 0.9891
# Fold [1/5] - Epoch 1/25 - Train Loss: 0.0781, Train Accuracy: 0.9825, Validation Loss: 0.1175, Validation Accuracy: 0.9669
# Fold [1/5] - Epoch 2/25 - Train Loss: 0.0776, Train Accuracy: 0.9825, Validation Loss: 0.1132, Validation Accuracy: 0.9669
# Fold [1/5] - Epoch 3/25 - Train Loss: 0.0771, Train Accuracy: 0.9825, Validation Loss: 0.1125, Validation Accuracy: 0.9669
# Fold [1/5] - Epoch 4/25 - Train Loss: 0.0767, Train Accuracy: 0.9825, Validation Loss: 0.1115, Validation Accuracy: 0.9669
# Fold [1/5] - Epoch 5/25 - Train Loss: 0.0763, Train Accuracy: 0.9825, Validation Loss: 0.1141, Validation Accuracy: 0.9669
# Fold [1/5] - Epoch 6/25 - Train Loss: 0.0758, Train Accuracy: 0.9825, Validation Loss: 0.1103, Validation Accuracy: 0.9669
# Fold [1/5] - Epoch 7/25 - Train Loss: 0.0754, Train Accuracy: 0.9825, Validation Loss: 0.1084, Validation Accuracy: 0.9669
# Fold [1/5] - Epoch 8/25 - Train Loss: 0.0749, Train Accuracy: 0.9825, Validation Loss: 0.1073, Validation Accuracy: 0.9669
# Fold [1/5] - Epoch 9/25 - Train Loss: 0.0745, Train Accuracy: 0.9825, Validation Loss: 0.1075, Validation Accuracy: 0.9669
# Fold [1/5] - Epoch 10/25 - Train Loss: 0.0740, Train Accuracy: 0.9825, Validation Loss: 0.1051, Validation Accuracy: 0.9669
# Fold [1/5] - Epoch 11/25 - Train Loss: 0.0735, Train Accuracy: 0.9825, Validation Loss: 0.1040, Validation Accuracy: 0.9669
# Fold [1/5] - Epoch 12/25 - Train Loss: 0.0730, Train Accuracy: 0.9825, Validation Loss: 0.1030, Validation Accuracy: 0.9669
# Fold [1/5] - Epoch 13/25 - Train Loss: 0.0725, Train Accuracy: 0.9825, Validation Loss: 0.1030, Validation Accuracy: 0.9669
# Fold [1/5] - Epoch 14/25 - Train Loss: 0.0721, Train Accuracy: 0.9825, Validation Loss: 0.1023, Validation Accuracy: 0.9669
# Fold [1/5] - Epoch 15/25 - Train Loss: 0.0716, Train Accuracy: 0.9825, Validation Loss: 0.1000, Validation Accuracy: 0.9669
# Fold [1/5] - Epoch 16/25 - Train Loss: 0.0710, Train Accuracy: 0.9825, Validation Loss: 0.0990, Validation Accuracy: 0.9669
# Fold [1/5] - Epoch 17/25 - Train Loss: 0.0705, Train Accuracy: 0.9825, Validation Loss: 0.0998, Validation Accuracy: 0.9669
# Fold [1/5] - Epoch 18/25 - Train Loss: 0.0700, Train Accuracy: 0.9825, Validation Loss: 0.0971, Validation Accuracy: 0.9669
# Fold [1/5] - Epoch 19/25 - Train Loss: 0.0695, Train Accuracy: 0.9825, Validation Loss: 0.0978, Validation Accuracy: 0.9669
# Fold [1/5] - Epoch 20/25 - Train Loss: 0.0690, Train Accuracy: 0.9825, Validation Loss: 0.0953, Validation Accuracy: 0.9669
# Fold [1/5] - Epoch 21/25 - Train Loss: 0.0685, Train Accuracy: 0.9825, Validation Loss: 0.0968, Validation Accuracy: 0.9669
# Fold [1/5] - Epoch 22/25 - Train Loss: 0.0731, Train Accuracy: 0.9825, Validation Loss: 0.0932, Validation Accuracy: 0.9669
# Fold [1/5] - Epoch 23/25 - Train Loss: 0.0675, Train Accuracy: 0.9825, Validation Loss: 0.0924, Validation Accuracy: 0.9669
# Fold [1/5] - Epoch 24/25 - Train Loss: 0.0719, Train Accuracy: 0.9825, Validation Loss: 0.0921, Validation Accuracy: 0.9669
# Fold [1/5] - Epoch 25/25 - Train Loss: 0.0665, Train Accuracy: 0.9825, Validation Loss: 0.0906, Validation Accuracy: 0.9669
# Fold [1/5] - Epoch 1/25 - Train Loss: 0.0679, Train Accuracy: 0.9815, Validation Loss: 0.0903, Validation Accuracy: 0.9707
# Fold [1/5] - Epoch 2/25 - Train Loss: 0.0654, Train Accuracy: 0.9815, Validation Loss: 0.0898, Validation Accuracy: 0.9707
# Fold [1/5] - Epoch 3/25 - Train Loss: 0.0648, Train Accuracy: 0.9815, Validation Loss: 0.0882, Validation Accuracy: 0.9707
# Fold [1/5] - Epoch 4/25 - Train Loss: 0.0641, Train Accuracy: 0.9815, Validation Loss: 0.0881, Validation Accuracy: 0.9707
# Fold [1/5] - Epoch 5/25 - Train Loss: 0.0636, Train Accuracy: 0.9815, Validation Loss: 0.0880, Validation Accuracy: 0.9707
# Fold [1/5] - Epoch 6/25 - Train Loss: 0.0630, Train Accuracy: 0.9815, Validation Loss: 0.0860, Validation Accuracy: 0.9707
# Fold [1/5] - Epoch 7/25 - Train Loss: 0.0623, Train Accuracy: 0.9815, Validation Loss: 0.0853, Validation Accuracy: 0.9707
# Fold [1/5] - Epoch 8/25 - Train Loss: 0.0617, Train Accuracy: 0.9815, Validation Loss: 0.0846, Validation Accuracy: 0.9707
# Fold [1/5] - Epoch 9/25 - Train Loss: 0.0611, Train Accuracy: 0.9815, Validation Loss: 0.0845, Validation Accuracy: 0.9707
# Fold [1/5] - Epoch 10/25 - Train Loss: 0.0605, Train Accuracy: 0.9815, Validation Loss: 0.0831, Validation Accuracy: 0.9707
# Fold [1/5] - Epoch 11/25 - Train Loss: 0.0599, Train Accuracy: 0.9815, Validation Loss: 0.0836, Validation Accuracy: 0.9707
# Fold [1/5] - Epoch 12/25 - Train Loss: 0.0593, Train Accuracy: 0.9815, Validation Loss: 0.0818, Validation Accuracy: 0.9707
# Fold [1/5] - Epoch 13/25 - Train Loss: 0.0588, Train Accuracy: 0.9815, Validation Loss: 0.0812, Validation Accuracy: 0.9707
# Fold [1/5] - Epoch 14/25 - Train Loss: 0.0581, Train Accuracy: 0.9815, Validation Loss: 0.0804, Validation Accuracy: 0.9707
# Fold [1/5] - Epoch 15/25 - Train Loss: 0.0575, Train Accuracy: 0.9815, Validation Loss: 0.0802, Validation Accuracy: 0.9707
# Fold [1/5] - Epoch 16/25 - Train Loss: 0.0568, Train Accuracy: 0.9815, Validation Loss: 0.0790, Validation Accuracy: 0.9707
# Fold [1/5] - Epoch 17/25 - Train Loss: 0.0562, Train Accuracy: 0.9815, Validation Loss: 0.0783, Validation Accuracy: 0.9707
# Fold [1/5] - Epoch 18/25 - Train Loss: 0.0556, Train Accuracy: 0.9815, Validation Loss: 0.0776, Validation Accuracy: 0.9707
# Fold [1/5] - Epoch 19/25 - Train Loss: 0.0549, Train Accuracy: 0.9815, Validation Loss: 0.0768, Validation Accuracy: 0.9707
# Fold [1/5] - Epoch 20/25 - Train Loss: 0.0543, Train Accuracy: 0.9815, Validation Loss: 0.0782, Validation Accuracy: 0.9707
# Fold [1/5] - Epoch 21/25 - Train Loss: 0.0537, Train Accuracy: 0.9815, Validation Loss: 0.0756, Validation Accuracy: 0.9707
# Fold [1/5] - Epoch 22/25 - Train Loss: 0.0531, Train Accuracy: 0.9815, Validation Loss: 0.0749, Validation Accuracy: 0.9707
# Fold [1/5] - Epoch 23/25 - Train Loss: 0.0524, Train Accuracy: 0.9815, Validation Loss: 0.0748, Validation Accuracy: 0.9707
# Fold [1/5] - Epoch 24/25 - Train Loss: 0.0518, Train Accuracy: 0.9815, Validation Loss: 0.0736, Validation Accuracy: 0.9707
# Fold [1/5] - Epoch 25/25 - Train Loss: 0.0512, Train Accuracy: 0.9815, Validation Loss: 0.0729, Validation Accuracy: 0.9707
# Fold [1/5] - Epoch 1/25 - Train Loss: 0.0552, Train Accuracy: 0.9783, Validation Loss: 0.0538, Validation Accuracy: 0.9837
# Fold [1/5] - Epoch 2/25 - Train Loss: 0.0544, Train Accuracy: 0.9783, Validation Loss: 0.0533, Validation Accuracy: 0.9837
# Fold [1/5] - Epoch 3/25 - Train Loss: 0.0537, Train Accuracy: 0.9783, Validation Loss: 0.0527, Validation Accuracy: 0.9837
# Fold [1/5] - Epoch 4/25 - Train Loss: 0.0530, Train Accuracy: 0.9783, Validation Loss: 0.0522, Validation Accuracy: 0.9837
# Fold [1/5] - Epoch 5/25 - Train Loss: 0.0523, Train Accuracy: 0.9783, Validation Loss: 0.0517, Validation Accuracy: 0.9837
# Fold [1/5] - Epoch 6/25 - Train Loss: 0.0516, Train Accuracy: 0.9783, Validation Loss: 0.0524, Validation Accuracy: 0.9837
# Fold [1/5] - Epoch 7/25 - Train Loss: 0.0509, Train Accuracy: 0.9787, Validation Loss: 0.0509, Validation Accuracy: 0.9837
# Fold [1/5] - Epoch 8/25 - Train Loss: 0.0564, Train Accuracy: 0.9798, Validation Loss: 0.0499, Validation Accuracy: 0.9837
# Fold [1/5] - Epoch 9/25 - Train Loss: 0.0496, Train Accuracy: 0.9806, Validation Loss: 0.0497, Validation Accuracy: 0.9837
# Fold [1/5] - Epoch 10/25 - Train Loss: 0.0490, Train Accuracy: 0.9814, Validation Loss: 0.0494, Validation Accuracy: 0.9837
# Fold [1/5] - Epoch 11/25 - Train Loss: 0.0483, Train Accuracy: 0.9819, Validation Loss: 0.0488, Validation Accuracy: 0.9837
# Fold [1/5] - Epoch 12/25 - Train Loss: 0.0475, Train Accuracy: 0.9833, Validation Loss: 0.0484, Validation Accuracy: 0.9837
# Fold [1/5] - Epoch 13/25 - Train Loss: 0.0468, Train Accuracy: 0.9844, Validation Loss: 0.0480, Validation Accuracy: 0.9837
# Fold [1/5] - Epoch 14/25 - Train Loss: 0.0470, Train Accuracy: 0.9851, Validation Loss: 0.0475, Validation Accuracy: 0.9837
# Fold [1/5] - Epoch 15/25 - Train Loss: 0.0455, Train Accuracy: 0.9860, Validation Loss: 0.0468, Validation Accuracy: 0.9837
# Fold [1/5] - Epoch 16/25 - Train Loss: 0.0448, Train Accuracy: 0.9863, Validation Loss: 0.0463, Validation Accuracy: 0.9837
# Fold [1/5] - Epoch 17/25 - Train Loss: 0.0442, Train Accuracy: 0.9866, Validation Loss: 0.0463, Validation Accuracy: 0.9837
# Fold [1/5] - Epoch 18/25 - Train Loss: 0.0442, Train Accuracy: 0.9867, Validation Loss: 0.0458, Validation Accuracy: 0.9848
# Fold [1/5] - Epoch 19/25 - Train Loss: 0.0430, Train Accuracy: 0.9875, Validation Loss: 0.0451, Validation Accuracy: 0.9848
# Fold [1/5] - Epoch 20/25 - Train Loss: 0.0424, Train Accuracy: 0.9879, Validation Loss: 0.0450, Validation Accuracy: 0.9848
# Fold [1/5] - Epoch 21/25 - Train Loss: 0.0419, Train Accuracy: 0.9879, Validation Loss: 0.0444, Validation Accuracy: 0.9864
# Fold [1/5] - Epoch 22/25 - Train Loss: 0.0413, Train Accuracy: 0.9879, Validation Loss: 0.0461, Validation Accuracy: 0.9864
# Fold [1/5] - Epoch 23/25 - Train Loss: 0.0407, Train Accuracy: 0.9879, Validation Loss: 0.0435, Validation Accuracy: 0.9864
# Fold [1/5] - Epoch 24/25 - Train Loss: 0.0402, Train Accuracy: 0.9882, Validation Loss: 0.0429, Validation Accuracy: 0.9864
# Fold [1/5] - Epoch 25/25 - Train Loss: 0.0396, Train Accuracy: 0.9889, Validation Loss: 0.0425, Validation Accuracy: 0.9864
# Fold [1/5] - Epoch 1/25 - Train Loss: 0.0408, Train Accuracy: 0.9886, Validation Loss: 0.0366, Validation Accuracy: 0.9891
# Fold [1/5] - Epoch 2/25 - Train Loss: 0.0402, Train Accuracy: 0.9889, Validation Loss: 0.0353, Validation Accuracy: 0.9891
# Fold [1/5] - Epoch 3/25 - Train Loss: 0.0395, Train Accuracy: 0.9885, Validation Loss: 0.0351, Validation Accuracy: 0.9891
# Fold [1/5] - Epoch 4/25 - Train Loss: 0.0390, Train Accuracy: 0.9890, Validation Loss: 0.0349, Validation Accuracy: 0.9891
# Fold [1/5] - Epoch 5/25 - Train Loss: 0.0383, Train Accuracy: 0.9889, Validation Loss: 0.0348, Validation Accuracy: 0.9902
# Fold [1/5] - Epoch 6/25 - Train Loss: 0.0377, Train Accuracy: 0.9890, Validation Loss: 0.0347, Validation Accuracy: 0.9891
# Fold [1/5] - Epoch 7/25 - Train Loss: 0.0371, Train Accuracy: 0.9891, Validation Loss: 0.0346, Validation Accuracy: 0.9891
# Fold [1/5] - Epoch 8/25 - Train Loss: 0.0366, Train Accuracy: 0.9890, Validation Loss: 0.0343, Validation Accuracy: 0.9908
# Fold [1/5] - Epoch 9/25 - Train Loss: 0.0361, Train Accuracy: 0.9890, Validation Loss: 0.0345, Validation Accuracy: 0.9897
# Fold [1/5] - Epoch 10/25 - Train Loss: 0.0355, Train Accuracy: 0.9890, Validation Loss: 0.0341, Validation Accuracy: 0.9913
# Fold [1/5] - Epoch 11/25 - Train Loss: 0.0350, Train Accuracy: 0.9889, Validation Loss: 0.0340, Validation Accuracy: 0.9913
# Fold [1/5] - Epoch 12/25 - Train Loss: 0.0349, Train Accuracy: 0.9890, Validation Loss: 0.0340, Validation Accuracy: 0.9913
# Fold [1/5] - Epoch 13/25 - Train Loss: 0.0340, Train Accuracy: 0.9895, Validation Loss: 0.0339, Validation Accuracy: 0.9902
# Fold [1/5] - Epoch 14/25 - Train Loss: 0.0335, Train Accuracy: 0.9889, Validation Loss: 0.0337, Validation Accuracy: 0.9902
# Fold [1/5] - Epoch 15/25 - Train Loss: 0.0330, Train Accuracy: 0.9893, Validation Loss: 0.0335, Validation Accuracy: 0.9913
# Fold [1/5] - Epoch 16/25 - Train Loss: 0.0325, Train Accuracy: 0.9895, Validation Loss: 0.0344, Validation Accuracy: 0.9913
# Fold [1/5] - Epoch 17/25 - Train Loss: 0.0321, Train Accuracy: 0.9898, Validation Loss: 0.0334, Validation Accuracy: 0.9913
# Fold [1/5] - Epoch 18/25 - Train Loss: 0.0317, Train Accuracy: 0.9897, Validation Loss: 0.0334, Validation Accuracy: 0.9913
# Fold [1/5] - Epoch 19/25 - Train Loss: 0.0312, Train Accuracy: 0.9900, Validation Loss: 0.0340, Validation Accuracy: 0.9913
# Fold [1/5] - Epoch 20/25 - Train Loss: 0.0308, Train Accuracy: 0.9902, Validation Loss: 0.0331, Validation Accuracy: 0.9913
# Fold [1/5] - Epoch 21/25 - Train Loss: 0.0304, Train Accuracy: 0.9905, Validation Loss: 0.0332, Validation Accuracy: 0.9913
# Fold [1/5] - Epoch 22/25 - Train Loss: 0.0299, Train Accuracy: 0.9912, Validation Loss: 0.0330, Validation Accuracy: 0.9913
# Fold [1/5] - Epoch 23/25 - Train Loss: 0.0296, Train Accuracy: 0.9906, Validation Loss: 0.0328, Validation Accuracy: 0.9913
# Fold [1/5] - Epoch 24/25 - Train Loss: 0.0292, Train Accuracy: 0.9913, Validation Loss: 0.0328, Validation Accuracy: 0.9913
# Fold [1/5] - Epoch 25/25 - Train Loss: 0.0288, Train Accuracy: 0.9910, Validation Loss: 0.0326, Validation Accuracy: 0.9908
# All models saved in all_enzyme_classifiers_20231023144851.pt

# %%
def predict(model, dataloader):
    model.eval()
    all_outputs = []
    with torch.no_grad():
        for inputs, _ in dataloader:
            inputs = inputs.cuda()
            outputs = model(inputs).squeeze().cpu().numpy()  # Ensure that we're flattening the output
            all_outputs.extend(outputs)
    return all_outputs

# %%
from itertools import chain

dataset = EnzymeDataset(enzyme_sequences, enzyme_labels)
loader = DataLoader(dataset, batch_size=32, shuffle=False)
all_scores = []

# Predict scores for each class using trained models
for model in models:
    scores = predict(model, loader)
    all_scores.append(scores)

# Transpose to have scores per instance rather than per class
all_scores = list(zip(*all_scores))

# Assign the enzyme class based on the highest score
predicted_classes = [scores.index(max(scores)) + 1 for scores in all_scores]

# Metrics: F1 Score and Accuracy
f1 = f1_score(enzyme_labels, predicted_classes, average='weighted')
accuracy = accuracy_score(enzyme_labels, predicted_classes)

print(f"F1 Score: {f1:.4f}")
print(f"Accuracy: {accuracy:.4f}")

# ROC curve
fpr = {}
tpr = {}
roc_auc = {}

for i, model in enumerate(models):
    scores = [score[i] for score in all_scores]  # Get scores for the i-th class across all samples
    binary_labels = [1 if label == i+1 else 0 for label in enzyme_labels]  # Create binary labels for the current class
    fpr[i], tpr[i], _ = roc_curve(binary_labels, scores)
    roc_auc[i] = auc(fpr[i], tpr[i])
    
    # Plotting
    fig, ax = plt.subplots()
    ax.plot(fpr[i], tpr[i], label=f'ROC curve (area = {roc_auc[i]:.2f})')
    ax.plot([0, 1], [0, 1], 'k--')
    ax.set_xlim([0.0, 1.05])
    ax.set_ylim([0.0, 1.05])
    ax.set_xlabel('False Positive Rate')
    ax.set_ylabel('True Positive Rate')
    ax.set_title(f'ROC Curve for Enzyme Class {i+1}')
    ax.legend(loc="lower right")
    plt.savefig("D:/Uni/PBL/RNN/roc"+str(i+1)+".png")
    plt.show()
    
    plt.close('all')

all_labels2 = np.array([int(x) for x in list(chain.from_iterable(list(chain.from_iterable([x.tolist() for x in list(chain.from_iterable(all_labels))]))))])
all_pred2 = np.array([round(x) for x in list(chain.from_iterable(list(chain.from_iterable([x.tolist() for x in list(chain.from_iterable(all_pred))]))))])


def bootstrap_statistic(y_true, y_pred, statistic_func, B=10_000, alpha=0.05):
    bootstrap_scores = []
    for _ in range(B):
        indices = np.random.choice(len(y_pred), len(y_pred), replace=True)
        resampled_pred = y_pred[indices]
        resampled_true = y_true[indices]
        score = statistic_func(resampled_true, resampled_pred)
        bootstrap_scores.append(score)
        

    mean_score = np.mean(bootstrap_scores)
    standard_error = np.std(bootstrap_scores, ddof=1)

    # Calculate the 95% confidence interval
    lower_bound = np.percentile(bootstrap_scores, (alpha / 2) * 100)
    upper_bound = np.percentile(bootstrap_scores, (1 - alpha / 2) * 100)

    return mean_score, standard_error, (lower_bound, upper_bound), bootstrap_scores

mean_score, standard_error, bounds, bootstrap_scores = bootstrap_statistic(all_labels2, all_pred2, calculate_f1)


# Set the range of values you want to plot (e.g., between 0.70 and 0.74)
min_value = 0.8
max_value = 0.99

# Filter data within the specified range
filtered_data = [x for x in bootstrap_scores if min_value <= x <= max_value]

# Create the histogram
plt.hist(filtered_data, bins=20, edgecolor='green')

# Set the title and labels
plt.title('Close-up Distribution Plot')
plt.xlabel('Values')
plt.ylabel('Frequency')

# Show the plot
plt.show()


initial_f1 = calculate_f1(all_labels2, all_pred2)
rounded_mean_f1, rounded_se_f1 = round_to_significance(mean_score, standard_error)
print(f"  - Initial F1 Score: {initial_f1:.2f}")
print(f"  - Mean ± SE: {rounded_mean_f1} ± {rounded_se_f1}")
print(f"  - 95% CI: [{bounds[0]:.2f}, {bounds[1]:.2f}]")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 9
#       7 # Predict scores for each class using trained models
#       8 for model in models:
# ----> 9     scores = predict(model, loader)
#      10     all_scores.append(scores)
#      12 # Transpose to have scores per instance rather than per class
#
# Cell In[9], line 2, in predict(model, dataloader)
#       1 def predict(model, dataloader):
# ----> 2     model.eval()
#       3     all_outputs = []
#       4     with torch.no_grad():
#
# AttributeError: 'NoneType' object has no attribute 'eval'
